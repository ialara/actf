# %% [markdown]
# # Guts

# %%
import numpy as np
from collections import Counter
rng = np.random.default_rng()

class Pilot:
    ftu_sorties = 59
    def __init__(self, i, f16_sorties=59, tos=0, experienced=False):
        self.id = i
        self.f16_sorties = f16_sorties
        self.tos = tos
        self.experienced = experienced
        self.arrived_month = 0
        self.in_ug = False
        self.ug = None
        self.ride_num = None
        self.quals = []
        self.tte = 0

    def set_arrived_month(self, month):
        self.arrived_month = month

    def increment_tos(self, months=1):
        self.tos += months

    def increment_f16_sorties(self, sortie_increment=1):
        self.f16_sorties += sortie_increment
        if self.in_ug:
          self.ride_num += sortie_increment

    def enroll_in_ug(self, ug, start_month=0):
        if self.in_ug:
            #print(f'PID {self.id} already enrolled in {self.ug}. {f"Did not enroll in {ug}." if self.ug != ug else ""}')
            return
        self.in_ug = True
        self.ug = ug
        self.ug_start_month = start_month
        self.ride_num = 0
        #print(f'PID {self.id} enrolled in {self.ug}.')
      
    def disenroll_from_ug(self):
        self.in_ug = False
        self.ug = None
        self.ride_num = None

    def award_qual(self, qual):
        if qual not in self.quals:
            self.quals.append(qual)

    def print_(self):
        msg = [f'ID: {self.id:2d} | EXP: {"Y" if self.experienced else "N"} | ',
               f'TOS: {self.tos:2d} | STY: {self.f16_sorties:3d} | ARR: {self.arrived_month:2d} | ',
               f'TTE: {self.tte if self.experienced else "- ":2} | QUAL: {self.quals}']
        if self.ug is not None:
            msg.append(f' | UG: {self.ug} #{self.ride_num}')

        print(*msg)

class Squadron:
    def __init__(self, name='default_Squadron', syllabi=None):
        self.name = name
        self.pilots = []
        self.gone_pilots = []
        self.absorbed_pilots = []
        self.pid = 0
        if syllabi is None:
            self.syllabi = {}

    def assign_pilot(self, pilot, arrived_month=0):
        self.pilots.append(pilot)
        pilot.set_arrived_month(arrived_month)

    def add_syllabi(self, syllabi):
        self.syllabi = syllabi

    def set_syllabus_ug_capacity(self, syllabus, capacity):
        syllabus.capacity = capacity

    def set_monthly_sorties_available(self, capacity=240):
        self.monthly_sorties_available = capacity

    def _next_pid(self):
        self.pid += 1
        return self.pid

    def get_pilot_by_id(self, id):
        pilot_dict = {p.id: p for p in self.pilots}
        pilot_dict.update({p.id: p for p in self.gone_pilots})
        return pilot_dict[id]

    def get_pilots_by_qual(self):
        quals = np.asarray(self._get_highest_quals())
        pilots = np.asarray(self.pilots)
      
        return {q: list(pilots[quals == q]) for q in Counter(quals).keys()}


    def populate_initial(self, num_pilots=36, prop_EXP=0.6, prop_IP=0.3):
        # num_EXP = rng.binomial(num_pilots, prop_EXP)
        # num_IP = rng.binomial(num_EXP, prop_IP)
        # num_INX = num_pilots - num_EXP

        num_EXP = int(num_pilots*prop_EXP) # API-1 45% EXP x 26 pilots + API-6 100% EXP x 10 pilots
        num_IP = int(num_pilots*prop_IP)
        num_INX = num_pilots - num_EXP

        # Parameters
        min_TOS_INX = 0
        max_TOS_INX = 24
        min_TOS_EXP = 0
        max_TOS_EXP = 24

        min_sorties_INX = Pilot.ftu_sorties
        max_sorties_INX = 250 # Syllabus.exp_sortie_rqmt < BREAKS EXCURSIONS removing/lessening sortie rqmts
        min_sorties_EXP = 250 # Syllabus.exp_sortie_rqmt
        max_sorties_EXP = 600 # 2*Syllabus.exp_sortie_rqmt

        # Assign INX pilots
        for _ in range(num_INX):
            my_tos = rng.integers(min_TOS_INX, max_TOS_INX)
            my_sorties = rng.integers(min_sorties_INX, max_sorties_INX)
            # Rough capping of sorties w/ TOS: Assume no more than 9 sorties per month
            # (Assume no "holdover" INX arrivals in initial population)
            my_sorties = min(my_sorties, min_sorties_INX + (my_tos+1)*9)
            inx_pilot = Pilot(self._next_pid(), f16_sorties=my_sorties, tos=my_tos)
            inx_pilot.initial_tos = my_tos # Debugging initial population

            inx_pilot.inflow_source = 'initial'
            inx_pilot.absorbable = True
            if inx_pilot.tos > 2: # Assume initial population completes MQT in specified timeline, and represents only first tour arrivals
                inx_pilot.increment_f16_sorties(9) # Duration of MQT
                inx_pilot.award_qual('WG')
                inx_pilot.inflow_source += ' WG'
            else: # These are new arrivals - assume all initial INX with 0 or 1 TOS
                  # are from FTU
                my_ug_prog = rng.integers(9) # MQT and FLUG have same duration
                # Assumptions: INX arrivals with 0 or 1 TOS are either new from FTU,
                # or "hold-overs" arriving INX from previous location
                ##if inx_pilot.f16_sorties < 75:
                inx_pilot.enroll_in_ug('MQT')
                #self.syllabi['MQT'].capacity -= 1
                inx_pilot.increment_f16_sorties(my_ug_prog)
                # elif inx_pilot.f16_sorties < 200:
                #     inx_pilot.award_qual('WG')
                #     inx_pilot.inflow_source += ' WG'
                #     if rng.random() < 0.7:
                #         inx_pilot.enroll_in_ug('FLUG')
                #         #self.syllabi['FLUG'].capacity -= 1
                #         inx_pilot.increment_f16_sorties(my_ug_prog)
                #         inx_pilot.inflow_source += '/FLUG'

                # else:
                #     inx_pilot.award_qual('WG')
                #     if rng.random() < 0.7:
                #         inx_pilot.award_qual('FL')
                #         inx_pilot.inflow_source += ' FL'
            self.assign_pilot(inx_pilot, arrived_month=-1*inx_pilot.tos)
          
        # Assign EXP pilots
        ips_remaining = num_IP
        for _ in range(num_EXP):
            my_tos = rng.integers(min_TOS_EXP, max_TOS_EXP)
            my_sorties = rng.integers(min_sorties_EXP, max_sorties_EXP)
            exp_pilot = Pilot(self._next_pid(), f16_sorties=my_sorties, tos=my_tos,
                              experienced = True)
            exp_pilot.award_qual(Syllabus.exp_qual_rqmt)
            exp_pilot.absorbable = False
            if exp_pilot.f16_sorties >= 284 and ips_remaining > 0: #275 based on Slab desired changes + 9 for IPUG -- make a parameter
                exp_pilot.award_qual('IP')
                ips_remaining -= 1
            # elif exp_pilot.f16_sorties >= 275:
            #     ipug_prob = min(1, 0.6 + int((exp_pilot.f16_sorties - 275)/30)*.15)
            #     if rng.random() < ipug_prob:
            #       exp_pilot.enroll_in_ug('IPUG')
            #       #self.syllabi['IPUG'].capacity -= 1
            #       exp_pilot.increment_f16_sorties(rng.integers(9))
            exp_pilot.initial_tos = my_tos
            self.assign_pilot(exp_pilot, arrived_month=-1*exp_pilot.tos)

    def inflow_from_ftu(self, num_pilots=15, arrival_month=0):
        new_ftus = []
        for _ in range(num_pilots):
            ftu_sortie_delta = rng.integers(-5, 5)
            my_f16_sorties = Pilot.ftu_sorties + ftu_sortie_delta
            new_pilot = Pilot(self._next_pid(), f16_sorties = my_f16_sorties)
            new_pilot.inflow_source = 'FTU'
            new_pilot.absorbable = True
            self.assign_pilot(new_pilot, arrived_month=arrival_month)
            new_ftus.append(new_pilot)
        
        return new_ftus

    def inflow_nth_tour(self, num_pilots=20, prop_IP=0.4, prop_WG=0.2, arrival_month=0):
        num_IP = rng.binomial(num_pilots, prop_IP)
        num_WG = rng.binomial(num_pilots, prop_WG)
        num_FL = num_pilots - num_IP - num_WG

        # Parameters
        min_sorties_WG = 200 # BREAKS EXCURSIONS changing sortie rqmt --> int(0.8*Syllabus.exp_sortie_rqmt)
        max_sorties_WG = 240 # (0.9*Syllabus.exp_sortie_rqmt)
        min_sorties_FL = 240 # int(0.9*Syllabus.exp_sortie_rqmt)
        max_sorties_FL = 500 # int(2*Syllabus.exp_sortie_rqmt)
        min_sorties_IP = 375 # int(1.5*Syllabus.exp_sortie_rqmt)
        max_sorties_IP = 1000 # 4*Syllabus.exp_sortie_rqmt

        new_nth = []
        for _ in range(num_IP):
            my_sorties = rng.integers(min_sorties_IP, max_sorties_IP)
            new_IP = Pilot(self._next_pid(), f16_sorties = my_sorties, experienced=True)
            new_IP.award_qual(Syllabus.exp_qual_rqmt)
            new_IP.award_qual('IP')
            self.assign_pilot(new_IP, arrived_month=arrival_month)
            new_IP.absorbable = False
            new_nth.append(new_IP)

        for _ in range(num_FL):
            my_sorties = rng.integers(min_sorties_FL, max_sorties_FL)
            new_FL = Pilot(self._next_pid(), f16_sorties = my_sorties)
            new_FL.award_qual('FL')
            new_FL.experienced = Syllabus.meets_EXP_criteria(new_FL.f16_sorties, new_FL.quals)
            new_FL.inflow_source = 'nth tour'
            self.assign_pilot(new_FL, arrived_month=arrival_month)
            new_FL.absorbable = False
            new_nth.append(new_FL)

        for _ in range(num_WG):
            my_sorties = rng.integers(min_sorties_WG, max_sorties_WG)
            new_WG = Pilot(self._next_pid(), f16_sorties = my_sorties)
            new_WG.award_qual('WG')
            new_WG.inflow_source = 'nth tour'
            new_WG.absorbable = False
            self.assign_pilot(new_WG, arrived_month=arrival_month)
            new_nth.append(new_WG)
        
        return new_nth
            
    def inflow_pilots(self, num_ftu=15, num_nth_tour=5, arrival_month=0):
        new_ftus = self.inflow_from_ftu(num_ftu, arrival_month=arrival_month)
        new_nth = self.inflow_nth_tour(num_nth_tour, arrival_month=arrival_month)
        ips = self.get_pilots_by_qual()['IP']
        for p in ips:
            assert p.experienced, f'IP {p.id} is not experienced.'
        return new_ftus, new_nth

    def outflow_pilots(self, tos_threshold=30):
        removed_pilots = [p for p in self.pilots if p.tos >= tos_threshold]
        for p in removed_pilots:
            if p.absorbable:
                p.absorbed = False
        self.pilots = [p for p in self.pilots if p not in set(removed_pilots)]
        self.gone_pilots.extend(removed_pilots)
        return removed_pilots

    def enroll_ug_students(self, start_month=0):
        pilots_by_quals = self.get_pilots_by_qual()

        try:
            mqt_candidates = pilots_by_quals['']
        except KeyError:
            mqt_candidates = []
        try:
            flug_candidates = pilots_by_quals['WG']
            flug_candidates = [p for p in flug_candidates if p.f16_sorties >= 175 and rng.random() < min(.5+int((p.f16_sorties-175)/30)*.15, 0.99)]
        except KeyError:
            flug_candidates = []
        try:
            ipug_candidates = pilots_by_quals['FL']
            ipug_candidates = [p for p in ipug_candidates if p.experienced and p.f16_sorties >= 275 and rng.random() < min(.5+int((p.f16_sorties-275)/30)*.15, 0.99)]
        except KeyError:
            ipug_candidates = []
            
        # Prioritize students (e.g. by TOS for MQT; sorties for FLUG/IPUG)
        mqt_candidates.sort(key=lambda x: (x.tos, x.f16_sorties), reverse=True)
        flug_candidates.sort(key=lambda x: x.f16_sorties, reverse=True)
        ipug_candidates.sort(key=lambda x: x.f16_sorties, reverse=True)
        # Enroll as many as possible, subject to capacity of upgrade program
        for students, program in zip([mqt_candidates, flug_candidates, ipug_candidates],
                                     [self.syllabi['MQT'], self.syllabi['FLUG'], self.syllabi['IPUG']]):
          # TODO: Note this is not guaranteed if programs have different capacities
          # (self.syllabi.values() order returned is random)
            enrollees = students[:program.capacity]
            for e in enrollees:
              e.enroll_in_ug(program.name, start_month=start_month)

    def fly_month(self, sorties_available=None, INX_tails_pct=0.33, fly_days=20):
        if sorties_available is None:
            sorties_available = self.monthly_sorties_available
        #INX_sorties = int(sorties_available * INX_sortie_pct)
        INX_pilots = [p for p in self.pilots if not p.experienced]

        for p in self.pilots:
            p.scm = 0

        rng.shuffle(INX_pilots)
        sorties_remaining = sorties_available
        inx_sorties_flown = 0
        inx_support_sorties_flown = 0
        # Essentially the theoretical SCM limit, accounting for student non-availability
        daily_inx_tails = min(len(INX_pilots), int((sorties_available / fly_days)*INX_tails_pct)) # Up to INX_tails_pct proportion of PMAI dedicated to absorbing pilot (MQT or WG).
        for p in INX_pilots:
            try:
                fls = self.get_pilots_by_qual()['FL']
            except KeyError:
                fls = []
            try:
                ips = self.get_pilots_by_qual()['IP']
            except KeyError:
                ips = []
            support_pool = fls + ips 
            support_pool = [spt for spt in support_pool if spt.id != p.id] # Cannot be own support
          # TODO: Confirm statistical correctness (probability and use of binomial)
          # Logic: 20 fly days per monthcalc
          # Assuming 10-turn-8 pattern, and each INX needing supervision,
          # 9 tails assignable to INX each day.
          # Even probability of assignment per student means p = 9 / num_INX.
            my_draw = rng.binomial(fly_days - p.scm, min(daily_inx_tails / len(INX_pilots), 0.99))
            my_SCM = max(min(my_draw, sorties_available), 0)
            p.scm = my_SCM
            #print(f'PID {p.id:2d}: drew {my_draw:2d}, flying {my_SCM:2d}. p.scm: {p.scm}')
            p.increment_f16_sorties(p.scm)
            # Increment for IPs/FLs
            if p.in_ug: # Can be either MQT or FLUG. UGs require IP supervision.
                if len(ips) > 0:
                    support_flown = rng.choice(ips, size=p.scm)
                    assert p.id not in set([spt.id for spt in support_flown]), f'Cannot be own support for PID {p.id}'
                else:
                    # No IPs available, no upgrades can happen
                    support_flown = []
                    # "Undo" scm assignment
                    p.increment_f16_sorties(-1*p.scm)
                    p.scm = 0
            elif self._get_highest_quals(pilots=[p]) == ['WG']: # This is a non-FLUG WG. Supervisable by any FL+.
                # try:
                #     support_pool = self.get_pilots_by_qual()['FL']
                # except KeyError:
                #     support_pool = self.get_pilots_by_qual()['IP']
                support_flown = rng.choice(support_pool, size=p.scm)
            else:
                support_flown = []
                assert p.id not in set([spt.id for spt in support_flown]), f'Cannot be own support for PID {p.id}'
            for support_pilot in support_flown:
                assert support_pilot.id != p.id, f'Cannot be own support for PID {p.id}'
                support_pilot.increment_f16_sorties()
                support_pilot.scm += 1
                inx_support_sorties_flown += 1
                sorties_remaining -= 1           
            sorties_remaining -= p.scm
            inx_sorties_flown += p.scm
            
        #print(*[f'{p.id}: {p.scm} | ' for p in INX_pilots])

        EXP_pilots = [p for p in self.pilots if p.experienced]
        EXP_sorties = max(sorties_remaining, 0)
        non_absorption_sorties = 0
        for p in EXP_pilots:
            assert p.id not in set([inx.id for inx in INX_pilots]), 'Pilot cannot be INX and EXP'
            my_draw = rng.binomial(fly_days - p.scm, min(len(EXP_pilots), ((sorties_available / fly_days) - 2*daily_inx_tails)) / len(EXP_pilots)) # <- 2x because absorption sorties require minimum 2 jets. 1 for UP and 1 for supervisor/IP.
            my_SCM = max(min(my_draw, sorties_remaining), 0)
            #print(f'PID {p.id:2d}: drew {my_draw:2d}, flying {my_SCM:2d}.')
            p.scm += my_SCM
            p.increment_f16_sorties(my_SCM)
            sorties_remaining -= my_SCM
            non_absorption_sorties += my_SCM

            

        print(f'EOM INX sorties flown: {inx_sorties_flown} (avg. {inx_sorties_flown / fly_days:.1f} per day / {inx_sorties_flown/len(INX_pilots):.1f} SCM [INX])')
        print(f'EOM INX support flown: {inx_support_sorties_flown}')
        print(f'-- Total EOM absorption sorties: {inx_sorties_flown + inx_support_sorties_flown} (avg. {(inx_sorties_flown + inx_support_sorties_flown) / fly_days:.1f} per fly day)')
        print(f'-- Total EOM non-absorption sorties: {non_absorption_sorties}')
        print(f'EOM total sorties remaining / available: {sorties_remaining} / {sorties_available} ({(sorties_available - sorties_remaining) / sorties_available:.1%} - avg. {(sorties_available - sorties_remaining) / fly_days:.1f} turned per day)')
        scms_inx = np.asarray([p.scm for p in self.pilots if not p.experienced])
        scms_exp = np.asarray([p.scm for p in self.pilots if p.experienced])
        print('EOM SCM summary:')
        print(f'--INX: min {min(scms_inx)} / mean {np.mean(scms_inx):.1f} / max {max(scms_inx)} / mode {Counter(scms_inx).most_common(1)}')
        print(f'--EXP: min {min(scms_exp)} / mean {np.mean(scms_exp):.1f} / max {max(scms_exp)} / mode {Counter(scms_exp).most_common(1)}')
        print()
        print('Monthly flight activity:')

        return {'INX': scms_inx, 'EXP': scms_exp}

    def update_qualifications(self, sim_month, ugs):
        ttes = []
        for p in self.pilots:
            was_experienced = p.experienced
            p.experienced = Syllabus.meets_EXP_criteria(p.f16_sorties, p.quals)
            if p.experienced and not was_experienced: # "became" EXP
                # Calculate TTE
                p.tte = sim_month - p.arrived_month
                print(f'!! PID {p.id:3d} experienced. TTE: {p.tte:2d} months. Inflow source? {p.inflow_source}')
                ttes.append({'PID': p.id, 'Source': p.inflow_source, 'TTE': p.tte, 'EXP month': sim_month, 'Absorbable': p.absorbable})
                if p.absorbable:
                    p.absorbed = True
            if p.in_ug and p.ride_num >= ugs[p.ug].duration:
                # Upgrade complete, award qualification
                print(f'PID {p.id:3d} completed {p.ug:4s} in {sim_month - p.ug_start_month:2d} months. Awarded {ugs[p.ug].award}.')
                p.award_qual(ugs[p.ug].award)
                #self.syllabi[p.ug].capacity += 1
                p.disenroll_from_ug()
        return ttes     

    def age_squadron(self, months=1):
        for p in self.pilots:
            p.increment_tos(months)

    def summarize(self):
        quals = Counter(self._get_highest_quals())
        ugs = Counter(self._get_ug_enrollment())
        exp = Counter(self._get_experience())

        exp_str = [f'{"EXP" if q else "INX":6s} -> {num:3d} | ' for q, num in exp.items()]
        print('EXPR:', *exp_str, f'PILOTS -> {exp[True] + exp[False]:3d} | {exp[True]/(exp[True]+exp[False])*100:.0f}% EXP')
        quals_str = [f'{q if q != "" else "(none)":6s} -> {num:3d} | ' for q, num in quals.items()]
        print('QUAL:', *quals_str)
        ugs_str = [f'{q if q is not None else "(none)":6s} -> {num:3d} | ' for q, num in ugs.items()]
        print('UPGS:', *ugs_str)

        return {'EXPR': exp,
                'QUAL': quals,
                'UPGS': ugs}

    def _get_highest_quals(self, pilots=None):
        if pilots is None:
            pilots = self.pilots
        return [p.quals[-1] if len(p.quals) > 0 else '' for p in pilots]

    def _get_ug_enrollment(self):
        return [p.ug for p in self.pilots]

    def _get_experience(self):
        return [p.experienced for p in self.pilots]

    def print_(self):
        for p in self.pilots:
            p.print_()

class Simulation:
    def __init__(self, run_num=0):
        self.run_num = run_num
        self.month_num = 0

    def setup(self, starting_sq=None, initial_size=20, monthly_sortie_capacity=240):
        if starting_sq is None:
            self.sq = Squadron('test_Squadron')
        self.syllabi = {s.name: s for s in [Syllabus('MQT', 9, 'WG'),
                                            Syllabus('FLUG', 9, 'FL'),
                                            Syllabus('IPUG', 9, 'IP')]}
        for syll in self.syllabi.values():
            syll.capacity = 4
        self.sq.add_syllabi(self.syllabi)
        self.sq.populate_initial(initial_size)
        self.sq.set_monthly_sorties_available(monthly_sortie_capacity)

        self.starting_sq = self.sq # To restore for multiple runs

    
    def _reset_sim_stats(self):
        self.sq = self.starting_sq
        self.month_num = 0

        # Stat tracking
        self.monthly_stats = {'SCM_INX': [],
                              'SCM_EXP': [],
                              'NUM_IN_UGS': [],
                              'NUM_BY_EXP': [],
                              'NUM_BY_QUAL': [],
                              'FIRST_ARRIVALS': [],
                              'NTH_ARRIVALS': [],
                              'FIRST_DEPARTURES': [],
                              'NTH_DEPARTURES': []}
        self.per_pilot_stats = {'TTE': [],
                                'DEP_MONTH': [],
                                'NUM_DEPARTED_INX': 0}


    def step_month(self, num_months=1, inflow_ftu=15, inflow_nth=5, tos_threshold=30, sorties_avail=None):
        for _ in range(num_months):
            self.month_num += 1
            print(f'---SIM MONTH {self.month_num}---')
            ftu_in, nth_in = self.sq.inflow_pilots(num_ftu=inflow_ftu, num_nth_tour=inflow_nth, arrival_month=self.month_num)
            self.monthly_stats['FIRST_ARRIVALS'].append(len(ftu_in))
            self.monthly_stats['NTH_ARRIVALS'].append(len(nth_in))
            print('>>>After inflow/enrollment:')
            if len(ftu_in) > 0:
                print(f'++ {len(ftu_in)}x MQT')
            if len(Counter(sim.sq._get_highest_quals(nth_in))) > 0:
                print(f'++ {[f"{num}x {qual}" for qual, num in Counter(sim.sq._get_highest_quals(nth_in)).items()]}')
            #self.sq.print_()
            self.sq.enroll_ug_students(start_month=self.month_num)
            # TODO: Tidy into a function
            summary = self.sq.summarize()
            self.monthly_stats['NUM_IN_UGS'].append(summary['UPGS'])
            self.monthly_stats['NUM_BY_QUAL'].append(summary['QUAL'])
            self.monthly_stats['NUM_BY_EXP'].append(summary['EXPR'])            
            print()
            scms = self.sq.fly_month(sorties_available=sorties_avail)
            self.monthly_stats['SCM_INX'].append(scms['INX'])
            self.monthly_stats['SCM_EXP'].append(scms['EXP'])
            #print('>>>After flying:')
            #self.sq.summarize()
            # for p in self.sq.pilots:
            #   print(f'PID {p.id} flew {p.scm} sorties.')
            self.sq.age_squadron()
            # print('After aging:')
            # self.sq.summarize()
            ttes = self.sq.update_qualifications(self.month_num, self.syllabi)
            if len(ttes) > 0:
                for tte in ttes:
                    self.per_pilot_stats['TTE'].append(tte)
            removed_pilots = self.sq.outflow_pilots(tos_threshold)
            self.per_pilot_stats['NUM_DEPARTED_INX'] += sum([not p.experienced for p in removed_pilots])
            for p in removed_pilots:
                p.departed_month = self.month_num
                self.per_pilot_stats['DEP_MONTH'].append({'PID': p.id, 'arr_month': p.arrived_month, 'dep_month': p.departed_month, 'TOS': p.departed_month - p.arrived_month})
            self.monthly_stats['FIRST_DEPARTURES'].append(sum([p.absorbable for p in removed_pilots]))
            self.monthly_stats['NTH_DEPARTURES'].append(sum([not p.absorbable for p in removed_pilots]))

            print()
            print(f'Pilots departed: {[f"{num}x {qual}" for qual, num in Counter(sim.sq._get_highest_quals(removed_pilots)).items()]}')
            print('>>>After outflow:')
            self.sq.summarize()
            print()

    def sim_run(self, ftu_arrival_calendar, nth_arrival_calendar, sortie_generation_calendar, run_months=60):
        self._reset_sim_stats()

        def repeat_yearly_calendars(run_months, calendar):
            if len(calendar) < run_months and len(calendar) % 12 == 0:
                reps = int(run_months / len(calendar))
                calendar = calendar * reps
            return calendar

        ftu_arrivals = repeat_yearly_calendars(run_months, ftu_arrival_calendar)
        nth_arrivals = repeat_yearly_calendars(run_months, nth_arrival_calendar)
        sortie_generation = repeat_yearly_calendars(run_months, sortie_generation_calendar)
        
        assert all(el == run_months for el in [len(ftu_arrivals), len(nth_arrivals), len(sortie_generation)]), 'Schedule length mismatch'
        
        for ftu, nth, sorties in zip(ftu_arrivals, nth_arrivals, sortie_generation):
            self.step_month(inflow_ftu=ftu, inflow_nth=nth, sorties_avail=sorties, tos_threshold=24)

    def many_runs(self, ftu_arrival_calendar, nth_arrival_calendar, sortie_generation_calendar, num_runs=100, months_per_run=60):
        run_stats = []
        for run in range(num_runs):
            self.sim_run(ftu_arrival_calendar, nth_arrival_calendar, sortie_generation_calendar, run_months=months_per_run)
            run_stats.append({'monthly': self.monthly_stats, 'pilot': self.per_pilot_stats})
            self.run_num += 1
        return run_stats

class Syllabus:
    exp_sortie_rqmt = 250
    exp_qual_rqmt = 'FL'
    def __init__(self, name, duration, award):
        self.name = name
        self.duration = duration
        self.award = award   
    @staticmethod
    def meets_EXP_criteria(pilot_sorties, pilot_qualifications):
        return (pilot_sorties >= Syllabus.exp_sortie_rqmt and 
               Syllabus.exp_qual_rqmt in pilot_qualifications)

# %%
sq = Squadron()

# %%
# sq = Squadron('test_Sq')
# sq.populate_initial(30)
# sq.summarize()

# %%
#sq.print_()

# %% [markdown]
# # Sim Setup

# %%
sim = Simulation()
sim.setup(initial_size=36)
sim.sq.summarize()
# Out:
# EXPR: INX    ->  15 |  EXP    ->  21 |  PILOTS ->  36 | 58% EXP
# QUAL: WG     ->  14 |  (none) ->   1 |  FL     ->  11 |  IP     ->  10 |
# UPGS: (none) ->  35 |  MQT    ->   1 |
# {'EXPR': Counter({False: 15, True: 21}),
#  'QUAL': Counter({'WG': 14, '': 1, 'FL': 11, 'IP': 10}),
#  'UPGS': Counter({None: 35, 'MQT': 1})}

# %% [markdown]
# # Scenario Inputs

# %%
#NUM_YEARS = 5
# Start rig
ftu_arrivals = [0, 0, 2, 0, 1, 0, 2, 0, 0, 2, 0, 1] #*NUM_YEARS
nth_arrivals = [0, 3, 0, 2, 0, 0, 0, 3, 0, 0, 2, 0] #*NUM_YEARS

# turn pattern
tails_go_1 = 12
tails_go_2 = 10
monthly_fly_days = 20

sortie_generation = [(tails_go_1 + tails_go_2)*monthly_fly_days]*12 #*NUM_YEARS

# # for ftu, nth, sorties in zip(ftu_arrivals, nth_arrivals, sortie_generation):
# #     sim.step_month(inflow_ftu=ftu, inflow_nth=nth, sorties_avail=sorties, tos_threshold=30)
    
# #sim.monthly_stats

# per_pilot = sim.per_pilot_stats
# monthly = sim.monthly_stats
# monthly.keys()

# %% [markdown]
# # Go! (One Run)

# %%
sim.sim_run(ftu_arrival_calendar=ftu_arrivals, nth_arrival_calendar=nth_arrivals, sortie_generation_calendar=sortie_generation)
# Out:
# ---SIM MONTH 1---
# >>>After inflow/enrollment:
# EXPR: INX    ->  15 |  EXP    ->  21 |  PILOTS ->  36 | 58% EXP
# QUAL: WG     ->  14 |  (none) ->   1 |  FL     ->  11 |  IP     ->  10 |
# UPGS: FLUG   ->   2 |  (none) ->  29 |  MQT    ->   1 |  IPUG   ->   4 |
#
# EOM INX sorties flown: 143 (avg. 7.2 per day / 9.5 SCM [INX])
# EOM INX support flown: 143
# -- Total EOM absorption sorties: 286 (avg. 14.3 per fly day)
# -- Total EOM non-absorption sorties: 108
# EOM total sorties remaining / available: 46 / 440 (89.5% - avg. 19.7 turned per day)
# EOM SCM summary:
# --INX: min 4 / mean 9.5 / max 15 / mode [(10, 3)]
# --EXP: min 6 / mean 12.0 / max 16 / mode [(12, 6)]
#
# Monthly flight activity:
# PID   1 completed FLUG in  0 months. Awarded FL.
# PID  10 completed MQT  in  1 months. Awarded WG.
# PID  30 completed IPUG in  0 months. Awarded IP.
# PID  32 completed IPUG in  0 months. Awarded IP.
# PID  34 completed IPUG in  0 months. Awarded IP.
# PID  36 completed IPUG in  0 months. Awarded IP.
#
# Pilots departed: ['1x WG']
# >>>After outflow:
# EXPR: INX    ->  14 |  EXP    ->  21 |  PILOTS ->  35 | 60% EXP
# QUAL: FL     ->   8 |  WG     ->  13 |  IP     ->  14 |
# UPGS: (none) ->  34 |  FLUG   ->   1 |
#
# ---SIM MONTH 2---
# >>>After inflow/enrollment:
# ++ ['3x FL']
# EXPR: INX    ->  14 |  EXP    ->  24 |  PILOTS ->  38 | 63% EXP
# QUAL: FL     ->  11 |  WG     ->  13 |  IP     ->  14 |
# UPGS: (none) ->  30 |  FLUG   ->   4 |  IPUG   ->   4 |
#
# EOM INX sorties flown: 136 (avg. 6.8 per day / 9.7 SCM [INX])
# EOM INX support flown: 126
# -- Total EOM absorption sorties: 262 (avg. 13.1 per fly day)
# -- Total EOM non-absorption sorties: 110
# EOM total sorties remaining / available: 68 / 440 (84.5% - avg. 18.6 turned per day)
# EOM SCM summary:
# --INX: min 6 / mean 9.7 / max 13 / mode [(10, 3)]
# --EXP: min 7 / mean 9.7 / max 15 / mode [(8, 8)]
#
# Monthly flight activity:
# PID   3 completed FLUG in  0 months. Awarded FL.
# PID   5 completed FLUG in  0 months. Awarded FL.
# PID  12 completed FLUG in  1 months. Awarded FL.
# PID  29 completed IPUG in  0 months. Awarded IP.
#
# Pilots departed: ['1x FL']
# >>>After outflow:
# EXPR: INX    ->  14 |  EXP    ->  23 |  PILOTS ->  37 | 62% EXP
# QUAL: FL     ->  12 |  WG     ->  10 |  IP     ->  15 |
# UPGS: (none) ->  33 |  FLUG   ->   1 |  IPUG   ->   3 |
#
# ---SIM MONTH 3---
# >>>After inflow/enrollment:
# ++ 2x MQT
# EXPR: INX    ->  16 |  EXP    ->  23 |  PILOTS ->  39 | 59% EXP
# QUAL: FL     ->  12 |  WG     ->  10 |  IP     ->  15 |  (none) ->   2 |
# UPGS: (none) ->  31 |  FLUG   ->   2 |  IPUG   ->   4 |  MQT    ->   2 |
#
# EOM INX sorties flown: 134 (avg. 6.7 per day / 8.4 SCM [INX])
# EOM INX support flown: 103
# -- Total EOM absorption sorties: 237 (avg. 11.8 per fly day)
# -- Total EOM non-absorption sorties: 132
# EOM total sorties remaining / available: 71 / 440 (83.9% - avg. 18.4 turned per day)
# EOM SCM summary:
# --INX: min 5 / mean 8.8 / max 11 / mode [(10, 5)]
# --EXP: min 5 / mean 9.7 / max 15 / mode [(11, 6)]
#
# Monthly flight activity:
# !! PID   1 experienced. TTE: 24 months. Inflow source? initial WG
# PID   4 completed FLUG in  0 months. Awarded FL.
# PID   9 completed FLUG in  1 months. Awarded FL.
# PID  28 completed IPUG in  1 months. Awarded IP.
# PID  33 completed IPUG in  0 months. Awarded IP.
# PID  37 completed IPUG in  1 months. Awarded IP.
# PID  39 completed IPUG in  1 months. Awarded IP.
# PID  41 completed MQT  in  0 months. Awarded WG.
#
# Pilots departed: ['1x FL', '3x IP']
# >>>After outflow:
# EXPR: INX    ->  15 |  EXP    ->  20 |  PILOTS ->  35 | 57% EXP
# QUAL: WG     ->   9 |  FL     ->   9 |  IP     ->  16 |  (none) ->   1 |
# UPGS: (none) ->  34 |  MQT    ->   1 |
#
# ---SIM MONTH 4---
# >>>After inflow/enrollment:
# ++ ['1x IP', '1x WG']
# EXPR: INX    ->  16 |  EXP    ->  21 |  PILOTS ->  37 | 57% EXP
# QUAL: WG     ->  10 |  FL     ->   9 |  IP     ->  17 |  (none) ->   1 |
# UPGS: (none) ->  35 |  MQT    ->   1 |  FLUG   ->   1 |
#
# EOM INX sorties flown: 141 (avg. 7.0 per day / 8.8 SCM [INX])
# EOM INX support flown: 100
# -- Total EOM absorption sorties: 241 (avg. 12.1 per fly day)
# -- Total EOM non-absorption sorties: 126
# EOM total sorties remaining / available: 73 / 440 (83.4% - avg. 18.4 turned per day)
# EOM SCM summary:
# --INX: min 5 / mean 9.3 / max 14 / mode [(11, 4)]
# --EXP: min 5 / mean 9.7 / max 13 / mode [(10, 7)]
#
# Monthly flight activity:
# PID  40 completed MQT  in  1 months. Awarded WG.
#
# Pilots departed: ['1x WG', '1x FL']
# >>>After outflow:
# EXPR: INX    ->  15 |  EXP    ->  20 |  PILOTS ->  35 | 57% EXP
# QUAL: WG     ->  10 |  FL     ->   8 |  IP     ->  17 |
# UPGS: (none) ->  34 |  FLUG   ->   1 |
#
# ---SIM MONTH 5---
# >>>After inflow/enrollment:
# ++ 1x MQT
# EXPR: INX    ->  16 |  EXP    ->  20 |  PILOTS ->  36 | 56% EXP
# QUAL: WG     ->  10 |  FL     ->   8 |  IP     ->  17 |  (none) ->   1 |
# UPGS: (none) ->  31 |  FLUG   ->   2 |  IPUG   ->   2 |  MQT    ->   1 |
#
# EOM INX sorties flown: 136 (avg. 6.8 per day / 8.5 SCM [INX])
# EOM INX support flown: 91
# -- Total EOM absorption sorties: 227 (avg. 11.3 per fly day)
# -- Total EOM non-absorption sorties: 120
# EOM total sorties remaining / available: 93 / 440 (78.9% - avg. 17.4 turned per day)
# EOM SCM summary:
# --INX: min 5 / mean 9.1 / max 13 / mode [(9, 4)]
# --EXP: min 7 / mean 10.0 / max 15 / mode [(9, 6)]
#
# Monthly flight activity:
# !! PID  12 experienced. TTE: 19 months. Inflow source? initial WG
# PID  13 completed FLUG in  0 months. Awarded FL.
# PID  16 completed IPUG in  0 months. Awarded IP.
# PID  31 completed IPUG in  0 months. Awarded IP.
# PID  43 completed FLUG in  1 months. Awarded FL.
#
# Pilots departed: ['1x FL', '1x IP']
# >>>After outflow:
# EXPR: INX    ->  14 |  EXP    ->  20 |  PILOTS ->  34 | 59% EXP
# QUAL: WG     ->   8 |  FL     ->   7 |  IP     ->  18 |  (none) ->   1 |
# UPGS: (none) ->  33 |  MQT    ->   1 |
#
# ---SIM MONTH 6---
# >>>After inflow/enrollment:
# EXPR: INX    ->  14 |  EXP    ->  20 |  PILOTS ->  34 | 59% EXP
# QUAL: WG     ->   8 |  FL     ->   7 |  IP     ->  18 |  (none) ->   1 |
# UPGS: (none) ->  32 |  IPUG   ->   1 |  MQT    ->   1 |
#
# EOM INX sorties flown: 133 (avg. 6.7 per day / 9.5 SCM [INX])
# EOM INX support flown: 88
# -- Total EOM absorption sorties: 221 (avg. 11.1 per fly day)
# -- Total EOM non-absorption sorties: 125
# EOM total sorties remaining / available: 94 / 440 (78.6% - avg. 17.3 turned per day)
# EOM SCM summary:
# --INX: min 7 / mean 10.3 / max 15 / mode [(8, 3)]
# --EXP: min 8 / mean 9.9 / max 16 / mode [(9, 6)]
#
# Monthly flight activity:
# PID  38 completed IPUG in  0 months. Awarded IP.
# PID  44 completed MQT  in  1 months. Awarded WG.
#
# Pilots departed: []
# >>>After outflow:
# EXPR: INX    ->  14 |  EXP    ->  20 |  PILOTS ->  34 | 59% EXP
# QUAL: WG     ->   9 |  FL     ->   6 |  IP     ->  19 |
# UPGS: (none) ->  34 |
#
# ---SIM MONTH 7---
# >>>After inflow/enrollment:
# ++ 2x MQT
# EXPR: INX    ->  16 |  EXP    ->  20 |  PILOTS ->  36 | 56% EXP
# QUAL: WG     ->   9 |  FL     ->   6 |  IP     ->  19 |  (none) ->   2 |
# UPGS: (none) ->  31 |  FLUG   ->   3 |  MQT    ->   2 |
#
# EOM INX sorties flown: 139 (avg. 7.0 per day / 8.7 SCM [INX])
# EOM INX support flown: 99
# -- Total EOM absorption sorties: 238 (avg. 11.9 per fly day)
# -- Total EOM non-absorption sorties: 134
# EOM total sorties remaining / available: 68 / 440 (84.5% - avg. 18.6 turned per day)
# EOM SCM summary:
# --INX: min 6 / mean 8.9 / max 13 / mode [(8, 6)]
# --EXP: min 8 / mean 11.1 / max 15 / mode [(13, 5)]
#
# Monthly flight activity:
# PID  11 completed FLUG in  0 months. Awarded FL.
# !! PID  13 experienced. TTE: 22 months. Inflow source? initial WG
# !! PID  43 experienced. TTE:  3 months. Inflow source? nth tour
# PID  45 completed MQT  in  0 months. Awarded WG.
# PID  46 completed MQT  in  0 months. Awarded WG.
#
# Pilots departed: ['1x FL']
# >>>After outflow:
# EXPR: INX    ->  13 |  EXP    ->  22 |  PILOTS ->  35 | 63% EXP
# QUAL: WG     ->  10 |  FL     ->   6 |  IP     ->  19 |
# UPGS: (none) ->  33 |  FLUG   ->   2 |
#
# ---SIM MONTH 8---
# >>>After inflow/enrollment:
# ++ ['3x FL']
# EXPR: INX    ->  14 |  EXP    ->  24 |  PILOTS ->  38 | 63% EXP
# QUAL: WG     ->  10 |  FL     ->   9 |  IP     ->  19 |
# UPGS: FLUG   ->   3 |  (none) ->  33 |  IPUG   ->   2 |
#
# EOM INX sorties flown: 152 (avg. 7.6 per day / 10.9 SCM [INX])
# EOM INX support flown: 105
# -- Total EOM absorption sorties: 257 (avg. 12.8 per fly day)
# -- Total EOM non-absorption sorties: 118
# EOM total sorties remaining / available: 65 / 440 (85.2% - avg. 18.8 turned per day)
# EOM SCM summary:
# --INX: min 7 / mean 11.4 / max 16 / mode [(9, 3)]
# --EXP: min 2 / mean 8.8 / max 16 / mode [(6, 4)]
#
# Monthly flight activity:
# PID   2 completed FLUG in  0 months. Awarded FL.
# !! PID   4 experienced. TTE: 18 months. Inflow source? initial WG
# PID   8 completed FLUG in  1 months. Awarded FL.
# !! PID   9 experienced. TTE: 24 months. Inflow source? initial WG
# PID  15 completed FLUG in  1 months. Awarded FL.
# !! PID  47 experienced. TTE:  0 months. Inflow source? nth tour
#
# Pilots departed: ['1x FL']
# >>>After outflow:
# EXPR: INX    ->  11 |  EXP    ->  26 |  PILOTS ->  37 | 70% EXP
# QUAL: FL     ->  11 |  WG     ->   7 |  IP     ->  19 |
# UPGS: (none) ->  35 |  IPUG   ->   2 |
#
# ---SIM MONTH 9---
# >>>After inflow/enrollment:
# EXPR: INX    ->  11 |  EXP    ->  26 |  PILOTS ->  37 | 70% EXP
# QUAL: FL     ->  11 |  WG     ->   7 |  IP     ->  19 |
# UPGS: (none) ->  34 |  IPUG   ->   3 |
#
# EOM INX sorties flown: 146 (avg. 7.3 per day / 13.3 SCM [INX])
# EOM INX support flown: 90
# -- Total EOM absorption sorties: 236 (avg. 11.8 per fly day)
# -- Total EOM non-absorption sorties: 136
# EOM total sorties remaining / available: 68 / 440 (84.5% - avg. 18.6 turned per day)
# EOM SCM summary:
# --INX: min 9 / mean 13.8 / max 20 / mode [(13, 3)]
# --EXP: min 4 / mean 8.2 / max 12 / mode [(10, 7)]
#
# Monthly flight activity:
# PID  12 completed IPUG in  0 months. Awarded IP.
# PID  48 completed IPUG in  1 months. Awarded IP.
# PID  49 completed IPUG in  1 months. Awarded IP.
#
# Pilots departed: ['1x FL', '1x IP']
# >>>After outflow:
# EXPR: INX    ->  11 |  EXP    ->  24 |  PILOTS ->  35 | 69% EXP
# QUAL: FL     ->   7 |  WG     ->   7 |  IP     ->  21 |
# UPGS: (none) ->  35 |
#
# ---SIM MONTH 10---
# >>>After inflow/enrollment:
# ++ 2x MQT
# EXPR: INX    ->  13 |  EXP    ->  24 |  PILOTS ->  37 | 65% EXP
# QUAL: FL     ->   7 |  WG     ->   7 |  IP     ->  21 |  (none) ->   2 |
# UPGS: (none) ->  34 |  FLUG   ->   1 |  MQT    ->   2 |
#
# EOM INX sorties flown: 144 (avg. 7.2 per day / 11.1 SCM [INX])
# EOM INX support flown: 111
# -- Total EOM absorption sorties: 255 (avg. 12.8 per fly day)
# -- Total EOM non-absorption sorties: 129
# EOM total sorties remaining / available: 56 / 440 (87.3% - avg. 19.2 turned per day)
# EOM SCM summary:
# --INX: min 6 / mean 11.5 / max 17 / mode [(11, 3)]
# --EXP: min 5 / mean 9.4 / max 14 / mode [(8, 7)]
#
# Monthly flight activity:
# PID  10 completed FLUG in  0 months. Awarded FL.
# !! PID  11 experienced. TTE: 18 months. Inflow source? initial WG
# PID  50 completed MQT  in  0 months. Awarded WG.
# PID  51 completed MQT  in  0 months. Awarded WG.
#
# Pilots departed: ['2x IP']
# >>>After outflow:
# EXPR: INX    ->  12 |  EXP    ->  23 |  PILOTS ->  35 | 66% EXP
# QUAL: FL     ->   8 |  WG     ->   8 |  IP     ->  19 |
# UPGS: (none) ->  35 |
#
# ---SIM MONTH 11---
# >>>After inflow/enrollment:
# ++ ['1x IP', '1x WG']
# EXPR: INX    ->  13 |  EXP    ->  24 |  PILOTS ->  37 | 65% EXP
# QUAL: FL     ->   8 |  WG     ->   9 |  IP     ->  20 |
# UPGS: (none) ->  34 |  FLUG   ->   2 |  IPUG   ->   1 |
#
# EOM INX sorties flown: 130 (avg. 6.5 per day / 10.0 SCM [INX])
# EOM INX support flown: 94
# -- Total EOM absorption sorties: 224 (avg. 11.2 per fly day)
# -- Total EOM non-absorption sorties: 137
# EOM total sorties remaining / available: 79 / 440 (82.0% - avg. 18.1 turned per day)
# EOM SCM summary:
# --INX: min 7 / mean 10.4 / max 16 / mode [(7, 3)]
# --EXP: min 4 / mean 9.1 / max 13 / mode [(10, 5)]
#
# Monthly flight activity:
# !! PID   8 experienced. TTE: 18 months. Inflow source? initial WG
# !! PID  15 experienced. TTE: 17 months. Inflow source? initial WG
# PID  53 completed FLUG in  0 months. Awarded FL.
#
# Pilots departed: ['1x IP']
# >>>After outflow:
# EXPR: INX    ->  11 |  EXP    ->  25 |  PILOTS ->  36 | 69% EXP
# QUAL: FL     ->   9 |  WG     ->   8 |  IP     ->  19 |
# UPGS: (none) ->  34 |  FLUG   ->   1 |  IPUG   ->   1 |
#
# ---SIM MONTH 12---
# >>>After inflow/enrollment:
# ++ 1x MQT
# EXPR: INX    ->  12 |  EXP    ->  25 |  PILOTS ->  37 | 68% EXP
# QUAL: FL     ->   9 |  WG     ->   8 |  IP     ->  19 |  (none) ->   1 |
# UPGS: (none) ->  34 |  FLUG   ->   1 |  IPUG   ->   1 |  MQT    ->   1 |
#
# EOM INX sorties flown: 138 (avg. 6.9 per day / 11.5 SCM [INX])
# EOM INX support flown: 104
# -- Total EOM absorption sorties: 242 (avg. 12.1 per fly day)
# -- Total EOM non-absorption sorties: 123
# EOM total sorties remaining / available: 75 / 440 (83.0% - avg. 18.2 turned per day)
# EOM SCM summary:
# --INX: min 8 / mean 11.8 / max 16 / mode [(11, 3)]
# --EXP: min 1 / mean 8.9 / max 14 / mode [(8, 6)]
#
# Monthly flight activity:
# PID  14 completed FLUG in  1 months. Awarded FL.
# PID  43 completed IPUG in  1 months. Awarded IP.
# PID  54 completed MQT  in  0 months. Awarded WG.
#
# Pilots departed: ['1x IP']
# >>>After outflow:
# EXPR: INX    ->  12 |  EXP    ->  24 |  PILOTS ->  36 | 67% EXP
# QUAL: FL     ->   9 |  IP     ->  19 |  WG     ->   8 |
# UPGS: (none) ->  36 |
#
# ---SIM MONTH 13---
# >>>After inflow/enrollment:
# EXPR: INX    ->  12 |  EXP    ->  24 |  PILOTS ->  36 | 67% EXP
# QUAL: FL     ->   9 |  IP     ->  19 |  WG     ->   8 |
# UPGS: (none) ->  35 |  IPUG   ->   1 |
#
# EOM INX sorties flown: 128 (avg. 6.4 per day / 10.7 SCM [INX])
# EOM INX support flown: 84
# -- Total EOM absorption sorties: 212 (avg. 10.6 per fly day)
# -- Total EOM non-absorption sorties: 130
# EOM total sorties remaining / available: 98 / 440 (77.7% - avg. 17.1 turned per day)
# EOM SCM summary:
# --INX: min 7 / mean 10.8 / max 13 / mode [(11, 4)]
# --EXP: min 4 / mean 8.7 / max 15 / mode [(8, 5)]
#
# Monthly flight activity:
# !! PID   2 experienced. TTE: 22 months. Inflow source? initial WG
#
# Pilots departed: ['1x IP']
# >>>After outflow:
# EXPR: EXP    ->  24 |  INX    ->  11 |  PILOTS ->  35 | 69% EXP
# QUAL: FL     ->   9 |  IP     ->  18 |  WG     ->   8 |
# UPGS: (none) ->  34 |  IPUG   ->   1 |
#
# ---SIM MONTH 14---
# >>>After inflow/enrollment:
# ++ ['2x FL', '1x WG']
# EXPR: EXP    ->  26 |  INX    ->  12 |  PILOTS ->  38 | 68% EXP
# QUAL: FL     ->  11 |  IP     ->  18 |  WG     ->   9 |
# UPGS: (none) ->  32 |  IPUG   ->   5 |  FLUG   ->   1 |
#
# EOM INX sorties flown: 128 (avg. 6.4 per day / 10.7 SCM [INX])
# EOM INX support flown: 102
# -- Total EOM absorption sorties: 230 (avg. 11.5 per fly day)
# -- Total EOM non-absorption sorties: 124
# EOM total sorties remaining / available: 86 / 440 (80.5% - avg. 17.7 turned per day)
# EOM SCM summary:
# --INX: min 6 / mean 10.7 / max 15 / mode [(12, 4)]
# --EXP: min 2 / mean 8.3 / max 12 / mode [(9, 7)]
#
# Monthly flight activity:
# PID  11 completed IPUG in  1 months. Awarded IP.
# PID  47 completed IPUG in  0 months. Awarded IP.
# !! PID  53 experienced. TTE:  3 months. Inflow source? nth tour
# PID  55 completed IPUG in  0 months. Awarded IP.
# PID  57 completed FLUG in  0 months. Awarded FL.
#
# Pilots departed: ['1x FL', '2x IP']
# >>>After outflow:
# EXPR: EXP    ->  24 |  INX    ->  11 |  PILOTS ->  35 | 69% EXP
# QUAL: FL     ->   8 |  IP     ->  19 |  WG     ->   8 |
# UPGS: (none) ->  34 |  IPUG   ->   1 |
#
# ---SIM MONTH 15---
# >>>After inflow/enrollment:
# ++ 2x MQT
# EXPR: EXP    ->  24 |  INX    ->  13 |  PILOTS ->  37 | 65% EXP
# QUAL: FL     ->   8 |  IP     ->  19 |  WG     ->   8 |  (none) ->   2 |
# UPGS: (none) ->  33 |  IPUG   ->   2 |  MQT    ->   2 |
#
# EOM INX sorties flown: 149 (avg. 7.5 per day / 11.5 SCM [INX])
# EOM INX support flown: 120
# -- Total EOM absorption sorties: 269 (avg. 13.4 per fly day)
# -- Total EOM non-absorption sorties: 124
# EOM total sorties remaining / available: 47 / 440 (89.3% - avg. 19.6 turned per day)
# EOM SCM summary:
# --INX: min 5 / mean 11.9 / max 18 / mode [(12, 4)]
# --EXP: min 4 / mean 9.7 / max 13 / mode [(9, 7)]
#
# Monthly flight activity:
# !! PID  10 experienced. TTE: 16 months. Inflow source? initial
# !! PID  14 experienced. TTE: 18 months. Inflow source? initial WG
# PID  15 completed IPUG in  0 months. Awarded IP.
# PID  56 completed IPUG in  1 months. Awarded IP.
# PID  58 completed MQT  in  0 months. Awarded WG.
# PID  59 completed MQT  in  0 months. Awarded WG.
#
# Pilots departed: ['1x FL']
# >>>After outflow:
# EXPR: EXP    ->  25 |  INX    ->  11 |  PILOTS ->  36 | 69% EXP
# QUAL: FL     ->   5 |  IP     ->  21 |  WG     ->  10 |
# UPGS: (none) ->  36 |
#
# ---SIM MONTH 16---
# >>>After inflow/enrollment:
# ++ ['2x IP']
# EXPR: EXP    ->  27 |  INX    ->  11 |  PILOTS ->  38 | 71% EXP
# QUAL: FL     ->   5 |  IP     ->  23 |  WG     ->  10 |
# UPGS: IPUG   ->   1 |  (none) ->  36 |  FLUG   ->   1 |
#
# EOM INX sorties flown: 150 (avg. 7.5 per day / 13.6 SCM [INX])
# EOM INX support flown: 135
# -- Total EOM absorption sorties: 285 (avg. 14.2 per fly day)
# -- Total EOM non-absorption sorties: 113
# EOM total sorties remaining / available: 42 / 440 (90.5% - avg. 19.9 turned per day)
# EOM SCM summary:
# --INX: min 11 / mean 13.9 / max 18 / mode [(14, 4)]
# --EXP: min 4 / mean 9.1 / max 13 / mode [(10, 11)]
#
# Monthly flight activity:
# PID   8 completed IPUG in  0 months. Awarded IP.
# PID  41 completed FLUG in  0 months. Awarded FL.
# !! PID  57 experienced. TTE:  2 months. Inflow source? nth tour
#
# Pilots departed: ['1x IP']
# >>>After outflow:
# EXPR: EXP    ->  27 |  INX    ->  10 |  PILOTS ->  37 | 73% EXP
# QUAL: IP     ->  23 |  FL     ->   5 |  WG     ->   9 |
# UPGS: (none) ->  37 |
#
# ---SIM MONTH 17---
# >>>After inflow/enrollment:
# ++ 1x MQT
# EXPR: EXP    ->  27 |  INX    ->  11 |  PILOTS ->  38 | 71% EXP
# QUAL: IP     ->  23 |  FL     ->   5 |  WG     ->   9 |  (none) ->   1 |
# UPGS: (none) ->  34 |  FLUG   ->   3 |  MQT    ->   1 |
#
# EOM INX sorties flown: 138 (avg. 6.9 per day / 12.5 SCM [INX])
# EOM INX support flown: 125
# -- Total EOM absorption sorties: 263 (avg. 13.2 per fly day)
# -- Total EOM non-absorption sorties: 121
# EOM total sorties remaining / available: 56 / 440 (87.3% - avg. 19.2 turned per day)
# EOM SCM summary:
# --INX: min 9 / mean 12.6 / max 15 / mode [(12, 4)]
# --EXP: min 5 / mean 9.0 / max 14 / mode [(8, 9)]
#
# Monthly flight activity:
# PID  40 completed FLUG in  0 months. Awarded FL.
# PID  44 completed FLUG in  0 months. Awarded FL.
# PID  45 completed FLUG in  0 months. Awarded FL.
# PID  62 completed MQT  in  0 months. Awarded WG.
#
# Pilots departed: ['2x IP']
# >>>After outflow:
# EXPR: EXP    ->  25 |  INX    ->  11 |  PILOTS ->  36 | 69% EXP
# QUAL: FL     ->   8 |  IP     ->  21 |  WG     ->   7 |
# UPGS: (none) ->  36 |
#
# ---SIM MONTH 18---
# >>>After inflow/enrollment:
# EXPR: EXP    ->  25 |  INX    ->  11 |  PILOTS ->  36 | 69% EXP
# QUAL: FL     ->   8 |  IP     ->  21 |  WG     ->   7 |
# UPGS: (none) ->  34 |  FLUG   ->   1 |  IPUG   ->   1 |
#
# EOM INX sorties flown: 133 (avg. 6.7 per day / 12.1 SCM [INX])
# EOM INX support flown: 83
# -- Total EOM absorption sorties: 216 (avg. 10.8 per fly day)
# -- Total EOM non-absorption sorties: 145
# EOM total sorties remaining / available: 79 / 440 (82.0% - avg. 18.1 turned per day)
# EOM SCM summary:
# --INX: min 9 / mean 12.8 / max 18 / mode [(11, 2)]
# --EXP: min 5 / mean 8.7 / max 14 / mode [(7, 5)]
#
# Monthly flight activity:
# PID  46 completed FLUG in  0 months. Awarded FL.
#
# Pilots departed: ['2x IP']
# >>>After outflow:
# EXPR: EXP    ->  23 |  INX    ->  11 |  PILOTS ->  34 | 68% EXP
# QUAL: FL     ->   9 |  IP     ->  19 |  WG     ->   6 |
# UPGS: (none) ->  33 |  IPUG   ->   1 |
#
# ---SIM MONTH 19---
# >>>After inflow/enrollment:
# ++ 2x MQT
# EXPR: EXP    ->  23 |  INX    ->  13 |  PILOTS ->  36 | 64% EXP
# QUAL: FL     ->   9 |  IP     ->  19 |  WG     ->   6 |  (none) ->   2 |
# UPGS: (none) ->  31 |  IPUG   ->   3 |  MQT    ->   2 |
#
# EOM INX sorties flown: 138 (avg. 6.9 per day / 10.6 SCM [INX])
# EOM INX support flown: 85
# -- Total EOM absorption sorties: 223 (avg. 11.2 per fly day)
# -- Total EOM non-absorption sorties: 126
# EOM total sorties remaining / available: 91 / 440 (79.3% - avg. 17.4 turned per day)
# EOM SCM summary:
# --INX: min 7 / mean 11.2 / max 14 / mode [(12, 5)]
# --EXP: min 4 / mean 8.6 / max 13 / mode [(9, 4)]
#
# Monthly flight activity:
# PID  14 completed IPUG in  0 months. Awarded IP.
# PID  53 completed IPUG in  1 months. Awarded IP.
# PID  57 completed IPUG in  0 months. Awarded IP.
# PID  63 completed MQT  in  0 months. Awarded WG.
# PID  64 completed MQT  in  0 months. Awarded WG.
#
# Pilots departed: ['4x IP']
# >>>After outflow:
# EXPR: EXP    ->  19 |  INX    ->  13 |  PILOTS ->  32 | 59% EXP
# QUAL: FL     ->   6 |  IP     ->  18 |  WG     ->   8 |
# UPGS: (none) ->  32 |
#
# ---SIM MONTH 20---
# >>>After inflow/enrollment:
# ++ ['2x IP', '1x FL']
# EXPR: EXP    ->  22 |  INX    ->  13 |  PILOTS ->  35 | 63% EXP
# QUAL: FL     ->   7 |  IP     ->  20 |  WG     ->   8 |
# UPGS: (none) ->  34 |  IPUG   ->   1 |
#
# EOM INX sorties flown: 136 (avg. 6.8 per day / 10.5 SCM [INX])
# EOM INX support flown: 87
# -- Total EOM absorption sorties: 223 (avg. 11.2 per fly day)
# -- Total EOM non-absorption sorties: 143
# EOM total sorties remaining / available: 74 / 440 (83.2% - avg. 18.3 turned per day)
# EOM SCM summary:
# --INX: min 5 / mean 11.1 / max 15 / mode [(13, 3)]
# --EXP: min 3 / mean 9.7 / max 14 / mode [(10, 5)]
#
# Monthly flight activity:
# !! PID  40 experienced. TTE: 17 months. Inflow source? FTU
# !! PID  41 experienced. TTE: 17 months. Inflow source? FTU
# !! PID  44 experienced. TTE: 15 months. Inflow source? FTU
# PID  67 completed IPUG in  0 months. Awarded IP.
#
# Pilots departed: []
# >>>After outflow:
# EXPR: EXP    ->  25 |  INX    ->  10 |  PILOTS ->  35 | 71% EXP
# QUAL: FL     ->   6 |  IP     ->  21 |  WG     ->   8 |
# UPGS: (none) ->  35 |
#
# ---SIM MONTH 21---
# >>>After inflow/enrollment:
# EXPR: EXP    ->  25 |  INX    ->  10 |  PILOTS ->  35 | 71% EXP
# QUAL: FL     ->   6 |  IP     ->  21 |  WG     ->   8 |
# UPGS: (none) ->  34 |  FLUG   ->   1 |
#
# EOM INX sorties flown: 144 (avg. 7.2 per day / 14.4 SCM [INX])
# EOM INX support flown: 121
# -- Total EOM absorption sorties: 265 (avg. 13.2 per fly day)
# -- Total EOM non-absorption sorties: 123
# EOM total sorties remaining / available: 52 / 440 (88.2% - avg. 19.4 turned per day)
# EOM SCM summary:
# --INX: min 10 / mean 14.7 / max 18 / mode [(16, 4)]
# --EXP: min 5 / mean 9.3 / max 14 / mode [(11, 6)]
#
# Monthly flight activity:
# !! PID  46 experienced. TTE: 14 months. Inflow source? FTU
# PID  51 completed FLUG in  0 months. Awarded FL.
#
# Pilots departed: ['2x IP']
# >>>After outflow:
# EXPR: EXP    ->  24 |  INX    ->   9 |  PILOTS ->  33 | 73% EXP
# QUAL: FL     ->   7 |  IP     ->  19 |  WG     ->   7 |
# UPGS: (none) ->  33 |
#
# ---SIM MONTH 22---
# >>>After inflow/enrollment:
# ++ 2x MQT
# EXPR: EXP    ->  24 |  INX    ->  11 |  PILOTS ->  35 | 69% EXP
# QUAL: FL     ->   7 |  IP     ->  19 |  WG     ->   7 |  (none) ->   2 |
# UPGS: IPUG   ->   1 |  (none) ->  31 |  FLUG   ->   1 |  MQT    ->   2 |
#
# EOM INX sorties flown: 142 (avg. 7.1 per day / 12.9 SCM [INX])
# EOM INX support flown: 122
# -- Total EOM absorption sorties: 264 (avg. 13.2 per fly day)
# -- Total EOM non-absorption sorties: 120
# EOM total sorties remaining / available: 56 / 440 (87.3% - avg. 19.2 turned per day)
# EOM SCM summary:
# --INX: min 9 / mean 13.5 / max 17 / mode [(15, 3)]
# --EXP: min 6 / mean 9.8 / max 14 / mode [(11, 4)]
#
# Monthly flight activity:
# !! PID  45 experienced. TTE: 15 months. Inflow source? FTU
# PID  50 completed FLUG in  0 months. Awarded FL.
# PID  68 completed MQT  in  0 months. Awarded WG.
# PID  69 completed MQT  in  0 months. Awarded WG.
#
# Pilots departed: []
# >>>After outflow:
# EXPR: EXP    ->  25 |  INX    ->  10 |  PILOTS ->  35 | 71% EXP
# QUAL: FL     ->   8 |  IP     ->  19 |  WG     ->   8 |
# UPGS: IPUG   ->   1 |  (none) ->  34 |
#
# ---SIM MONTH 23---
# >>>After inflow/enrollment:
# ++ ['1x IP', '1x FL']
# EXPR: EXP    ->  27 |  INX    ->  10 |  PILOTS ->  37 | 73% EXP
# QUAL: FL     ->   9 |  IP     ->  20 |  WG     ->   8 |
# UPGS: IPUG   ->   3 |  (none) ->  33 |  FLUG   ->   1 |
#
# EOM INX sorties flown: 143 (avg. 7.2 per day / 14.3 SCM [INX])
# EOM INX support flown: 116
# -- Total EOM absorption sorties: 259 (avg. 12.9 per fly day)
# -- Total EOM non-absorption sorties: 118
# EOM total sorties remaining / available: 63 / 440 (85.7% - avg. 18.9 turned per day)
# EOM SCM summary:
# --INX: min 10 / mean 14.5 / max 17 / mode [(14, 3)]
# --EXP: min 3 / mean 8.6 / max 15 / mode [(9, 7)]
#
# Monthly flight activity:
# PID  10 completed IPUG in  1 months. Awarded IP.
# PID  41 completed IPUG in  0 months. Awarded IP.
# PID  54 completed FLUG in  0 months. Awarded FL.
#
# Pilots departed: ['2x IP']
# >>>After outflow:
# EXPR: EXP    ->  25 |  INX    ->  10 |  PILOTS ->  35 | 71% EXP
# QUAL: IP     ->  20 |  FL     ->   8 |  WG     ->   7 |
# UPGS: (none) ->  34 |  IPUG   ->   1 |
#
# ---SIM MONTH 24---
# >>>After inflow/enrollment:
# ++ 1x MQT
# EXPR: EXP    ->  25 |  INX    ->  11 |  PILOTS ->  36 | 69% EXP
# QUAL: IP     ->  20 |  FL     ->   8 |  WG     ->   7 |  (none) ->   1 |
# UPGS: (none) ->  34 |  IPUG   ->   1 |  MQT    ->   1 |
#
# EOM INX sorties flown: 126 (avg. 6.3 per day / 11.5 SCM [INX])
# EOM INX support flown: 89
# -- Total EOM absorption sorties: 215 (avg. 10.8 per fly day)
# -- Total EOM non-absorption sorties: 136
# EOM total sorties remaining / available: 89 / 440 (79.8% - avg. 17.6 turned per day)
# EOM SCM summary:
# --INX: min 9 / mean 11.6 / max 15 / mode [(9, 3)]
# --EXP: min 6 / mean 8.7 / max 12 / mode [(8, 6)]
#
# Monthly flight activity:
# !! PID  51 experienced. TTE: 14 months. Inflow source? FTU
# PID  71 completed IPUG in  1 months. Awarded IP.
# PID  72 completed MQT  in  0 months. Awarded WG.
#
# Pilots departed: []
# >>>After outflow:
# EXPR: EXP    ->  26 |  INX    ->  10 |  PILOTS ->  36 | 72% EXP
# QUAL: IP     ->  21 |  FL     ->   7 |  WG     ->   8 |
# UPGS: (none) ->  36 |
#
# ---SIM MONTH 25---
# >>>After inflow/enrollment:
# EXPR: EXP    ->  26 |  INX    ->  10 |  PILOTS ->  36 | 72% EXP
# QUAL: IP     ->  21 |  FL     ->   7 |  WG     ->   8 |
# UPGS: (none) ->  33 |  IPUG   ->   2 |  FLUG   ->   1 |
#
# EOM INX sorties flown: 138 (avg. 6.9 per day / 13.8 SCM [INX])
# EOM INX support flown: 110
# -- Total EOM absorption sorties: 248 (avg. 12.4 per fly day)
# -- Total EOM non-absorption sorties: 131
# EOM total sorties remaining / available: 61 / 440 (86.1% - avg. 18.9 turned per day)
# EOM SCM summary:
# --INX: min 11 / mean 14.2 / max 17 / mode [(12, 3)]
# --EXP: min 5 / mean 9.0 / max 13 / mode [(10, 6)]
#
# Monthly flight activity:
# PID  40 completed IPUG in  0 months. Awarded IP.
# !! PID  50 experienced. TTE: 15 months. Inflow source? FTU
# PID  58 completed FLUG in  0 months. Awarded FL.
#
# Pilots departed: ['3x IP']
# >>>After outflow:
# EXPR: EXP    ->  24 |  INX    ->   9 |  PILOTS ->  33 | 73% EXP
# QUAL: IP     ->  19 |  FL     ->   7 |  WG     ->   7 |
# UPGS: (none) ->  32 |  IPUG   ->   1 |
#
# ---SIM MONTH 26---
# >>>After inflow/enrollment:
# ++ ['3x IP', '1x WG']
# EXPR: EXP    ->  27 |  INX    ->  10 |  PILOTS ->  37 | 73% EXP
# QUAL: IP     ->  22 |  FL     ->   7 |  WG     ->   8 |
# UPGS: (none) ->  34 |  IPUG   ->   1 |  FLUG   ->   2 |
#
# EOM INX sorties flown: 134 (avg. 6.7 per day / 13.4 SCM [INX])
# EOM INX support flown: 110
# -- Total EOM absorption sorties: 244 (avg. 12.2 per fly day)
# -- Total EOM non-absorption sorties: 126
# EOM total sorties remaining / available: 70 / 440 (84.1% - avg. 18.5 turned per day)
# EOM SCM summary:
# --INX: min 10 / mean 13.9 / max 19 / mode [(12, 3)]
# --EXP: min 4 / mean 8.4 / max 12 / mode [(10, 6)]
#
# Monthly flight activity:
# PID  44 completed IPUG in  1 months. Awarded IP.
# !! PID  54 experienced. TTE: 14 months. Inflow source? FTU
# PID  59 completed FLUG in  0 months. Awarded FL.
# PID  76 completed FLUG in  0 months. Awarded FL.
#
# Pilots departed: ['2x IP']
# >>>After outflow:
# EXPR: EXP    ->  26 |  INX    ->   9 |  PILOTS ->  35 | 74% EXP
# QUAL: IP     ->  21 |  FL     ->   8 |  WG     ->   6 |
# UPGS: (none) ->  35 |
#
# ---SIM MONTH 27---
# >>>After inflow/enrollment:
# ++ 2x MQT
# EXPR: EXP    ->  26 |  INX    ->  11 |  PILOTS ->  37 | 70% EXP
# QUAL: IP     ->  21 |  FL     ->   8 |  WG     ->   6 |  (none) ->   2 |
# UPGS: (none) ->  34 |  IPUG   ->   1 |  MQT    ->   2 |
#
# EOM INX sorties flown: 140 (avg. 7.0 per day / 12.7 SCM [INX])
# EOM INX support flown: 102
# -- Total EOM absorption sorties: 242 (avg. 12.1 per fly day)
# -- Total EOM non-absorption sorties: 128
# EOM total sorties remaining / available: 70 / 440 (84.1% - avg. 18.5 turned per day)
# EOM SCM summary:
# --INX: min 8 / mean 13.6 / max 17 / mode [(16, 2)]
# --EXP: min 5 / mean 8.5 / max 12 / mode [(8, 6)]
#
# Monthly flight activity:
# PID  77 completed MQT  in  0 months. Awarded WG.
# PID  78 completed MQT  in  0 months. Awarded WG.
#
# Pilots departed: ['2x IP']
# >>>After outflow:
# EXPR: EXP    ->  24 |  INX    ->  11 |  PILOTS ->  35 | 69% EXP
# QUAL: IP     ->  19 |  FL     ->   8 |  WG     ->   8 |
# UPGS: (none) ->  34 |  IPUG   ->   1 |
#
# ---SIM MONTH 28---
# >>>After inflow/enrollment:
# ++ ['1x IP', '1x FL']
# EXPR: EXP    ->  26 |  INX    ->  11 |  PILOTS ->  37 | 70% EXP
# QUAL: IP     ->  20 |  FL     ->   9 |  WG     ->   8 |
# UPGS: (none) ->  30 |  IPUG   ->   4 |  FLUG   ->   3 |
#
# EOM INX sorties flown: 151 (avg. 7.5 per day / 13.7 SCM [INX])
# EOM INX support flown: 115
# -- Total EOM absorption sorties: 266 (avg. 13.3 per fly day)
# -- Total EOM non-absorption sorties: 122
# EOM total sorties remaining / available: 52 / 440 (88.2% - avg. 19.4 turned per day)
# EOM SCM summary:
# --INX: min 11 / mean 13.9 / max 17 / mode [(13, 4)]
# --EXP: min 4 / mean 8.9 / max 13 / mode [(10, 5)]
#
# Monthly flight activity:
# PID  45 completed IPUG in  1 months. Awarded IP.
# PID  62 completed FLUG in  0 months. Awarded FL.
# PID  63 completed FLUG in  0 months. Awarded FL.
# PID  64 completed FLUG in  0 months. Awarded FL.
# !! PID  76 experienced. TTE:  2 months. Inflow source? nth tour
# PID  80 completed IPUG in  0 months. Awarded IP.
#
# Pilots departed: ['1x IP']
# >>>After outflow:
# EXPR: EXP    ->  26 |  INX    ->  10 |  PILOTS ->  36 | 72% EXP
# QUAL: IP     ->  21 |  FL     ->  10 |  WG     ->   5 |
# UPGS: (none) ->  34 |  IPUG   ->   2 |
#
# ---SIM MONTH 29---
# >>>After inflow/enrollment:
# ++ 1x MQT
# EXPR: EXP    ->  26 |  INX    ->  11 |  PILOTS ->  37 | 70% EXP
# QUAL: IP     ->  21 |  FL     ->  10 |  WG     ->   5 |  (none) ->   1 |
# UPGS: (none) ->  34 |  IPUG   ->   2 |  MQT    ->   1 |
#
# EOM INX sorties flown: 146 (avg. 7.3 per day / 13.3 SCM [INX])
# EOM INX support flown: 84
# -- Total EOM absorption sorties: 230 (avg. 11.5 per fly day)
# -- Total EOM non-absorption sorties: 147
# EOM total sorties remaining / available: 63 / 440 (85.7% - avg. 18.9 turned per day)
# EOM SCM summary:
# --INX: min 9 / mean 13.5 / max 15 / mode [(15, 4)]
# --EXP: min 4 / mean 8.3 / max 12 / mode [(6, 5)]
#
# Monthly flight activity:
# PID  46 completed IPUG in  1 months. Awarded IP.
# PID  51 completed IPUG in  1 months. Awarded IP.
# !! PID  58 experienced. TTE: 14 months. Inflow source? FTU
# !! PID  59 experienced. TTE: 14 months. Inflow source? FTU
# PID  81 completed MQT  in  0 months. Awarded WG.
#
# Pilots departed: []
# >>>After outflow:
# EXPR: EXP    ->  28 |  INX    ->   9 |  PILOTS ->  37 | 76% EXP
# QUAL: IP     ->  23 |  FL     ->   8 |  WG     ->   6 |
# UPGS: (none) ->  37 |
#
# ---SIM MONTH 30---
# >>>After inflow/enrollment:
# EXPR: EXP    ->  28 |  INX    ->   9 |  PILOTS ->  37 | 76% EXP
# QUAL: IP     ->  23 |  FL     ->   8 |  WG     ->   6 |
# UPGS: (none) ->  36 |  IPUG   ->   1 |
#
# EOM INX sorties flown: 134 (avg. 6.7 per day / 14.9 SCM [INX])
# EOM INX support flown: 90
# -- Total EOM absorption sorties: 224 (avg. 11.2 per fly day)
# -- Total EOM non-absorption sorties: 130
# EOM total sorties remaining / available: 86 / 440 (80.5% - avg. 17.7 turned per day)
# EOM SCM summary:
# --INX: min 12 / mean 16.0 / max 22 / mode [(15, 4)]
# --EXP: min 2 / mean 7.5 / max 13 / mode [(6, 4)]
#
# Monthly flight activity:
# !! PID  62 experienced. TTE: 13 months. Inflow source? FTU
#
# Pilots departed: ['2x IP']
# >>>After outflow:
# EXPR: EXP    ->  27 |  INX    ->   8 |  PILOTS ->  35 | 77% EXP
# QUAL: IP     ->  21 |  FL     ->   8 |  WG     ->   6 |
# UPGS: (none) ->  34 |  IPUG   ->   1 |
#
# ---SIM MONTH 31---
# >>>After inflow/enrollment:
# ++ 2x MQT
# EXPR: EXP    ->  27 |  INX    ->  10 |  PILOTS ->  37 | 73% EXP
# QUAL: IP     ->  21 |  FL     ->   8 |  WG     ->   6 |  (none) ->   2 |
# UPGS: (none) ->  33 |  IPUG   ->   1 |  FLUG   ->   1 |  MQT    ->   2 |
#
# EOM INX sorties flown: 144 (avg. 7.2 per day / 14.4 SCM [INX])
# EOM INX support flown: 116
# -- Total EOM absorption sorties: 260 (avg. 13.0 per fly day)
# -- Total EOM non-absorption sorties: 120
# EOM total sorties remaining / available: 60 / 440 (86.4% - avg. 19.0 turned per day)
# EOM SCM summary:
# --INX: min 7 / mean 14.7 / max 18 / mode [(17, 2)]
# --EXP: min 4 / mean 8.6 / max 13 / mode [(7, 6)]
#
# Monthly flight activity:
# PID  54 completed IPUG in  1 months. Awarded IP.
# PID  69 completed FLUG in  0 months. Awarded FL.
# PID  82 completed MQT  in  0 months. Awarded WG.
# PID  83 completed MQT  in  0 months. Awarded WG.
#
# Pilots departed: ['3x IP']
# >>>After outflow:
# EXPR: EXP    ->  24 |  INX    ->  10 |  PILOTS ->  34 | 71% EXP
# QUAL: FL     ->   8 |  IP     ->  19 |  WG     ->   7 |
# UPGS: (none) ->  34 |
#
# ---SIM MONTH 32---
# >>>After inflow/enrollment:
# ++ ['1x IP', '2x FL']
# EXPR: EXP    ->  27 |  INX    ->  10 |  PILOTS ->  37 | 73% EXP
# QUAL: FL     ->  10 |  IP     ->  20 |  WG     ->   7 |
# UPGS: IPUG   ->   2 |  (none) ->  35 |
#
# EOM INX sorties flown: 132 (avg. 6.6 per day / 13.2 SCM [INX])
# EOM INX support flown: 100
# -- Total EOM absorption sorties: 232 (avg. 11.6 per fly day)
# -- Total EOM non-absorption sorties: 128
# EOM total sorties remaining / available: 80 / 440 (81.8% - avg. 18.0 turned per day)
# EOM SCM summary:
# --INX: min 13 / mean 13.9 / max 15 / mode [(13, 4)]
# --EXP: min 4 / mean 7.7 / max 14 / mode [(8, 6)]
#
# Monthly flight activity:
# !! PID  63 experienced. TTE: 13 months. Inflow source? FTU
# !! PID  64 experienced. TTE: 13 months. Inflow source? FTU
# PID  86 completed IPUG in  0 months. Awarded IP.
#
# Pilots departed: []
# >>>After outflow:
# EXPR: EXP    ->  29 |  INX    ->   8 |  PILOTS ->  37 | 78% EXP
# QUAL: FL     ->   9 |  IP     ->  21 |  WG     ->   7 |
# UPGS: IPUG   ->   1 |  (none) ->  36 |
#
# ---SIM MONTH 33---
# >>>After inflow/enrollment:
# EXPR: EXP    ->  29 |  INX    ->   8 |  PILOTS ->  37 | 78% EXP
# QUAL: FL     ->   9 |  IP     ->  21 |  WG     ->   7 |
# UPGS: IPUG   ->   2 |  (none) ->  34 |  FLUG   ->   1 |
#
# EOM INX sorties flown: 140 (avg. 7.0 per day / 17.5 SCM [INX])
# EOM INX support flown: 125
# -- Total EOM absorption sorties: 265 (avg. 13.2 per fly day)
# -- Total EOM non-absorption sorties: 128
# EOM total sorties remaining / available: 47 / 440 (89.3% - avg. 19.6 turned per day)
# EOM SCM summary:
# --INX: min 15 / mean 17.5 / max 20 / mode [(18, 3)]
# --EXP: min 4 / mean 8.7 / max 12 / mode [(9, 8)]
#
# Monthly flight activity:
# PID  50 completed IPUG in  1 months. Awarded IP.
# PID  68 completed FLUG in  0 months. Awarded FL.
# PID  85 completed IPUG in  0 months. Awarded IP.
#
# Pilots departed: ['2x IP']
# >>>After outflow:
# EXPR: EXP    ->  27 |  INX    ->   8 |  PILOTS ->  35 | 77% EXP
# QUAL: IP     ->  21 |  FL     ->   8 |  WG     ->   6 |
# UPGS: (none) ->  35 |
#
# ---SIM MONTH 34---
# >>>After inflow/enrollment:
# ++ 2x MQT
# EXPR: EXP    ->  27 |  INX    ->  10 |  PILOTS ->  37 | 73% EXP
# QUAL: IP     ->  21 |  FL     ->   8 |  WG     ->   6 |  (none) ->   2 |
# UPGS: (none) ->  33 |  FLUG   ->   1 |  IPUG   ->   1 |  MQT    ->   2 |
#
# EOM INX sorties flown: 136 (avg. 6.8 per day / 13.6 SCM [INX])
# EOM INX support flown: 112
# -- Total EOM absorption sorties: 248 (avg. 12.4 per fly day)
# -- Total EOM non-absorption sorties: 132
# EOM total sorties remaining / available: 60 / 440 (86.4% - avg. 19.0 turned per day)
# EOM SCM summary:
# --INX: min 12 / mean 13.8 / max 16 / mode [(14, 3)]
# --EXP: min 5 / mean 9.0 / max 15 / mode [(9, 5)]
#
# Monthly flight activity:
# PID  72 completed FLUG in  0 months. Awarded FL.
# PID  76 completed IPUG in  0 months. Awarded IP.
# PID  87 completed MQT  in  0 months. Awarded WG.
# PID  88 completed MQT  in  0 months. Awarded WG.
#
# Pilots departed: ['2x IP']
# >>>After outflow:
# EXPR: EXP    ->  25 |  INX    ->  10 |  PILOTS ->  35 | 71% EXP
# QUAL: IP     ->  20 |  FL     ->   8 |  WG     ->   7 |
# UPGS: (none) ->  35 |
#
# ---SIM MONTH 35---
# >>>After inflow/enrollment:
# ++ ['1x IP', '1x FL']
# EXPR: EXP    ->  27 |  INX    ->  10 |  PILOTS ->  37 | 73% EXP
# QUAL: IP     ->  21 |  FL     ->   9 |  WG     ->   7 |
# UPGS: (none) ->  33 |  IPUG   ->   4 |
#
# EOM INX sorties flown: 131 (avg. 6.5 per day / 13.1 SCM [INX])
# EOM INX support flown: 98
# -- Total EOM absorption sorties: 229 (avg. 11.4 per fly day)
# -- Total EOM non-absorption sorties: 143
# EOM total sorties remaining / available: 68 / 440 (84.5% - avg. 18.6 turned per day)
# EOM SCM summary:
# --INX: min 9 / mean 13.4 / max 19 / mode [(12, 2)]
# --EXP: min 3 / mean 8.5 / max 14 / mode [(9, 6)]
#
# Monthly flight activity:
# PID  58 completed IPUG in  0 months. Awarded IP.
# PID  62 completed IPUG in  0 months. Awarded IP.
# PID  64 completed IPUG in  0 months. Awarded IP.
# !! PID  69 experienced. TTE: 13 months. Inflow source? FTU
#
# Pilots departed: ['1x IP']
# >>>After outflow:
# EXPR: EXP    ->  27 |  INX    ->   9 |  PILOTS ->  36 | 75% EXP
# QUAL: IP     ->  23 |  FL     ->   6 |  WG     ->   7 |
# UPGS: (none) ->  35 |  IPUG   ->   1 |
#
# ---SIM MONTH 36---
# >>>After inflow/enrollment:
# ++ 1x MQT
# EXPR: EXP    ->  27 |  INX    ->  10 |  PILOTS ->  37 | 73% EXP
# QUAL: IP     ->  23 |  FL     ->   6 |  WG     ->   7 |  (none) ->   1 |
# UPGS: (none) ->  34 |  IPUG   ->   2 |  MQT    ->   1 |
#
# EOM INX sorties flown: 137 (avg. 6.8 per day / 13.7 SCM [INX])
# EOM INX support flown: 112
# -- Total EOM absorption sorties: 249 (avg. 12.4 per fly day)
# -- Total EOM non-absorption sorties: 125
# EOM total sorties remaining / available: 66 / 440 (85.0% - avg. 18.7 turned per day)
# EOM SCM summary:
# --INX: min 7 / mean 13.8 / max 17 / mode [(15, 4)]
# --EXP: min 4 / mean 8.4 / max 14 / mode [(8, 6)]
#
# Monthly flight activity:
# !! PID  68 experienced. TTE: 14 months. Inflow source? FTU
# PID  90 completed IPUG in  1 months. Awarded IP.
#
# Pilots departed: []
# >>>After outflow:
# EXPR: EXP    ->  28 |  INX    ->   9 |  PILOTS ->  37 | 76% EXP
# QUAL: IP     ->  24 |  FL     ->   5 |  WG     ->   7 |  (none) ->   1 |
# UPGS: (none) ->  35 |  IPUG   ->   1 |  MQT    ->   1 |
#
# ---SIM MONTH 37---
# >>>After inflow/enrollment:
# EXPR: EXP    ->  28 |  INX    ->   9 |  PILOTS ->  37 | 76% EXP
# QUAL: IP     ->  24 |  FL     ->   5 |  WG     ->   7 |  (none) ->   1 |
# UPGS: (none) ->  33 |  IPUG   ->   1 |  FLUG   ->   2 |  MQT    ->   1 |
#
# EOM INX sorties flown: 136 (avg. 6.8 per day / 15.1 SCM [INX])
# EOM INX support flown: 127
# -- Total EOM absorption sorties: 263 (avg. 13.2 per fly day)
# -- Total EOM non-absorption sorties: 110
# EOM total sorties remaining / available: 67 / 440 (84.8% - avg. 18.6 turned per day)
# EOM SCM summary:
# --INX: min 9 / mean 15.1 / max 18 / mode [(18, 2)]
# --EXP: min 3 / mean 8.3 / max 12 / mode [(10, 6)]
#
# Monthly flight activity:
# PID  63 completed IPUG in  1 months. Awarded IP.
# !! PID  72 experienced. TTE: 13 months. Inflow source? FTU
# PID  77 completed FLUG in  0 months. Awarded FL.
# PID  78 completed FLUG in  0 months. Awarded FL.
# PID  91 completed MQT  in  1 months. Awarded WG.
#
# Pilots departed: ['3x IP']
# >>>After outflow:
# EXPR: EXP    ->  26 |  INX    ->   8 |  PILOTS ->  34 | 76% EXP
# QUAL: IP     ->  22 |  FL     ->   6 |  WG     ->   6 |
# UPGS: (none) ->  34 |
#
# ---SIM MONTH 38---
# >>>After inflow/enrollment:
# ++ ['1x IP', '1x FL', '1x WG']
# EXPR: EXP    ->  28 |  INX    ->   9 |  PILOTS ->  37 | 76% EXP
# QUAL: IP     ->  23 |  FL     ->   7 |  WG     ->   7 |
# UPGS: (none) ->  36 |  IPUG   ->   1 |
#
# EOM INX sorties flown: 140 (avg. 7.0 per day / 15.6 SCM [INX])
# EOM INX support flown: 107
# -- Total EOM absorption sorties: 247 (avg. 12.3 per fly day)
# -- Total EOM non-absorption sorties: 123
# EOM total sorties remaining / available: 70 / 440 (84.1% - avg. 18.5 turned per day)
# EOM SCM summary:
# --INX: min 13 / mean 16.0 / max 19 / mode [(15, 3)]
# --EXP: min 4 / mean 8.0 / max 11 / mode [(8, 7)]
#
# Monthly flight activity:
# !! PID  77 experienced. TTE: 11 months. Inflow source? FTU
#
# Pilots departed: ['1x IP', '1x FL']
# >>>After outflow:
# EXPR: EXP    ->  27 |  INX    ->   8 |  PILOTS ->  35 | 77% EXP
# QUAL: IP     ->  22 |  FL     ->   6 |  WG     ->   7 |
# UPGS: (none) ->  35 |
#
# ---SIM MONTH 39---
# >>>After inflow/enrollment:
# ++ 2x MQT
# EXPR: EXP    ->  27 |  INX    ->  10 |  PILOTS ->  37 | 73% EXP
# QUAL: IP     ->  22 |  FL     ->   6 |  WG     ->   7 |  (none) ->   2 |
# UPGS: (none) ->  32 |  FLUG   ->   3 |  MQT    ->   2 |
#
# EOM INX sorties flown: 136 (avg. 6.8 per day / 13.6 SCM [INX])
# EOM INX support flown: 126
# -- Total EOM absorption sorties: 262 (avg. 13.1 per fly day)
# -- Total EOM non-absorption sorties: 121
# EOM total sorties remaining / available: 57 / 440 (87.0% - avg. 19.1 turned per day)
# EOM SCM summary:
# --INX: min 11 / mean 13.9 / max 17 / mode [(14, 3)]
# --EXP: min 4 / mean 9.0 / max 14 / mode [(11, 4)]
#
# Monthly flight activity:
# !! PID  78 experienced. TTE: 12 months. Inflow source? FTU
# PID  81 completed FLUG in  0 months. Awarded FL.
# PID  82 completed FLUG in  0 months. Awarded FL.
# PID  94 completed FLUG in  0 months. Awarded FL.
# PID  95 completed MQT  in  0 months. Awarded WG.
# PID  96 completed MQT  in  0 months. Awarded WG.
#
# Pilots departed: ['2x IP']
# >>>After outflow:
# EXPR: EXP    ->  26 |  INX    ->   9 |  PILOTS ->  35 | 74% EXP
# QUAL: IP     ->  20 |  FL     ->   9 |  WG     ->   6 |
# UPGS: (none) ->  35 |
#
# ---SIM MONTH 40---
# >>>After inflow/enrollment:
# ++ ['2x FL']
# EXPR: EXP    ->  28 |  INX    ->   9 |  PILOTS ->  37 | 76% EXP
# QUAL: IP     ->  20 |  FL     ->  11 |  WG     ->   6 |
# UPGS: (none) ->  32 |  IPUG   ->   4 |  FLUG   ->   1 |
#
# EOM INX sorties flown: 138 (avg. 6.9 per day / 15.3 SCM [INX])
# EOM INX support flown: 96
# -- Total EOM absorption sorties: 234 (avg. 11.7 per fly day)
# -- Total EOM non-absorption sorties: 132
# EOM total sorties remaining / available: 74 / 440 (83.2% - avg. 18.3 turned per day)
# EOM SCM summary:
# --INX: min 12 / mean 15.6 / max 18 / mode [(16, 2)]
# --EXP: min 3 / mean 7.8 / max 14 / mode [(8, 9)]
#
# Monthly flight activity:
# PID  72 completed IPUG in  0 months. Awarded IP.
# PID  83 completed FLUG in  0 months. Awarded FL.
# !! PID  94 experienced. TTE:  2 months. Inflow source? nth tour
#
# Pilots departed: ['1x IP']
# >>>After outflow:
# EXPR: EXP    ->  28 |  INX    ->   8 |  PILOTS ->  36 | 78% EXP
# QUAL: IP     ->  20 |  FL     ->  11 |  WG     ->   5 |
# UPGS: (none) ->  33 |  IPUG   ->   3 |
#
# ---SIM MONTH 41---
# >>>After inflow/enrollment:
# ++ 1x MQT
# EXPR: EXP    ->  28 |  INX    ->   9 |  PILOTS ->  37 | 76% EXP
# QUAL: IP     ->  20 |  FL     ->  11 |  WG     ->   5 |  (none) ->   1 |
# UPGS: (none) ->  32 |  IPUG   ->   4 |  MQT    ->   1 |
#
# EOM INX sorties flown: 131 (avg. 6.5 per day / 14.6 SCM [INX])
# EOM INX support flown: 86
# -- Total EOM absorption sorties: 217 (avg. 10.8 per fly day)
# -- Total EOM non-absorption sorties: 147
# EOM total sorties remaining / available: 76 / 440 (82.7% - avg. 18.2 turned per day)
# EOM SCM summary:
# --INX: min 13 / mean 15.0 / max 17 / mode [(15, 3)]
# --EXP: min 4 / mean 8.1 / max 13 / mode [(7, 6)]
#
# Monthly flight activity:
# PID  68 completed IPUG in  1 months. Awarded IP.
# !! PID  81 experienced. TTE: 12 months. Inflow source? FTU
# PID  97 completed IPUG in  1 months. Awarded IP.
# PID  99 completed MQT  in  0 months. Awarded WG.
#
# Pilots departed: []
# >>>After outflow:
# EXPR: EXP    ->  29 |  INX    ->   8 |  PILOTS ->  37 | 78% EXP
# QUAL: IP     ->  22 |  FL     ->   9 |  WG     ->   6 |
# UPGS: (none) ->  35 |  IPUG   ->   2 |
#
# ---SIM MONTH 42---
# >>>After inflow/enrollment:
# EXPR: EXP    ->  29 |  INX    ->   8 |  PILOTS ->  37 | 78% EXP
# QUAL: IP     ->  22 |  FL     ->   9 |  WG     ->   6 |
# UPGS: (none) ->  34 |  IPUG   ->   3 |
#
# EOM INX sorties flown: 130 (avg. 6.5 per day / 16.2 SCM [INX])
# EOM INX support flown: 101
# -- Total EOM absorption sorties: 231 (avg. 11.6 per fly day)
# -- Total EOM non-absorption sorties: 133
# EOM total sorties remaining / available: 76 / 440 (82.7% - avg. 18.2 turned per day)
# EOM SCM summary:
# --INX: min 13 / mean 16.2 / max 20 / mode [(16, 2)]
# --EXP: min 5 / mean 7.9 / max 11 / mode [(7, 7)]
#
# Monthly flight activity:
# PID  69 completed IPUG in  0 months. Awarded IP.
# !! PID  83 experienced. TTE: 11 months. Inflow source? FTU
# PID  94 completed IPUG in  1 months. Awarded IP.
# PID  98 completed IPUG in  2 months. Awarded IP.
#
# Pilots departed: ['2x IP']
# >>>After outflow:
# EXPR: EXP    ->  28 |  INX    ->   7 |  PILOTS ->  35 | 80% EXP
# QUAL: IP     ->  23 |  FL     ->   6 |  WG     ->   6 |
# UPGS: (none) ->  35 |
#
# ---SIM MONTH 43---
# >>>After inflow/enrollment:
# ++ 2x MQT
# EXPR: EXP    ->  28 |  INX    ->   9 |  PILOTS ->  37 | 76% EXP
# QUAL: IP     ->  23 |  FL     ->   6 |  WG     ->   6 |  (none) ->   2 |
# UPGS: (none) ->  34 |  FLUG   ->   1 |  MQT    ->   2 |
#
# EOM INX sorties flown: 134 (avg. 6.7 per day / 14.9 SCM [INX])
# EOM INX support flown: 120
# -- Total EOM absorption sorties: 254 (avg. 12.7 per fly day)
# -- Total EOM non-absorption sorties: 127
# EOM total sorties remaining / available: 59 / 440 (86.6% - avg. 19.1 turned per day)
# EOM SCM summary:
# --INX: min 12 / mean 15.0 / max 18 / mode [(15, 2)]
# --EXP: min 4 / mean 8.7 / max 12 / mode [(9, 7)]
#
# Monthly flight activity:
# !! PID  82 experienced. TTE: 12 months. Inflow source? FTU
# PID  87 completed FLUG in  0 months. Awarded FL.
# PID 100 completed MQT  in  0 months. Awarded WG.
# PID 101 completed MQT  in  0 months. Awarded WG.
#
# Pilots departed: ['3x IP']
# >>>After outflow:
# EXPR: EXP    ->  26 |  INX    ->   8 |  PILOTS ->  34 | 76% EXP
# QUAL: IP     ->  20 |  FL     ->   7 |  WG     ->   7 |
# UPGS: (none) ->  34 |
#
# ---SIM MONTH 44---
# >>>After inflow/enrollment:
# ++ ['2x FL', '1x WG']
# EXPR: EXP    ->  28 |  INX    ->   9 |  PILOTS ->  37 | 76% EXP
# QUAL: IP     ->  20 |  FL     ->   9 |  WG     ->   8 |
# UPGS: (none) ->  32 |  IPUG   ->   4 |  FLUG   ->   1 |
#
# EOM INX sorties flown: 141 (avg. 7.0 per day / 15.7 SCM [INX])
# EOM INX support flown: 127
# -- Total EOM absorption sorties: 268 (avg. 13.4 per fly day)
# -- Total EOM non-absorption sorties: 102
# EOM total sorties remaining / available: 70 / 440 (84.1% - avg. 18.5 turned per day)
# EOM SCM summary:
# --INX: min 12 / mean 16.1 / max 19 / mode [(18, 2)]
# --EXP: min 2 / mean 8.0 / max 13 / mode [(7, 6)]
#
# Monthly flight activity:
# PID  88 completed FLUG in  0 months. Awarded FL.
#
# Pilots departed: []
# >>>After outflow:
# EXPR: EXP    ->  28 |  INX    ->   9 |  PILOTS ->  37 | 76% EXP
# QUAL: IP     ->  20 |  FL     ->  10 |  WG     ->   7 |
# UPGS: (none) ->  33 |  IPUG   ->   4 |
#
# ---SIM MONTH 45---
# >>>After inflow/enrollment:
# EXPR: EXP    ->  28 |  INX    ->   9 |  PILOTS ->  37 | 76% EXP
# QUAL: IP     ->  20 |  FL     ->  10 |  WG     ->   7 |
# UPGS: (none) ->  33 |  IPUG   ->   4 |
#
# EOM INX sorties flown: 124 (avg. 6.2 per day / 13.8 SCM [INX])
# EOM INX support flown: 98
# -- Total EOM absorption sorties: 222 (avg. 11.1 per fly day)
# -- Total EOM non-absorption sorties: 140
# EOM total sorties remaining / available: 78 / 440 (82.3% - avg. 18.1 turned per day)
# EOM SCM summary:
# --INX: min 12 / mean 13.8 / max 16 / mode [(14, 3)]
# --EXP: min 2 / mean 8.2 / max 14 / mode [(10, 7)]
#
# Monthly flight activity:
# PID  77 completed IPUG in  1 months. Awarded IP.
# PID  78 completed IPUG in  1 months. Awarded IP.
# !! PID  88 experienced. TTE: 11 months. Inflow source? FTU
# PID 102 completed IPUG in  1 months. Awarded IP.
# PID 103 completed IPUG in  1 months. Awarded IP.
#
# Pilots departed: ['2x IP']
# >>>After outflow:
# EXPR: EXP    ->  27 |  INX    ->   8 |  PILOTS ->  35 | 77% EXP
# QUAL: IP     ->  22 |  FL     ->   6 |  WG     ->   7 |
# UPGS: (none) ->  35 |
#
# ---SIM MONTH 46---
# >>>After inflow/enrollment:
# ++ 2x MQT
# EXPR: EXP    ->  27 |  INX    ->  10 |  PILOTS ->  37 | 73% EXP
# QUAL: IP     ->  22 |  FL     ->   6 |  WG     ->   7 |  (none) ->   2 |
# UPGS: (none) ->  31 |  IPUG   ->   3 |  FLUG   ->   1 |  MQT    ->   2 |
#
# EOM INX sorties flown: 139 (avg. 7.0 per day / 13.9 SCM [INX])
# EOM INX support flown: 125
# -- Total EOM absorption sorties: 264 (avg. 13.2 per fly day)
# -- Total EOM non-absorption sorties: 132
# EOM total sorties remaining / available: 44 / 440 (90.0% - avg. 19.8 turned per day)
# EOM SCM summary:
# --INX: min 10 / mean 13.9 / max 17 / mode [(14, 2)]
# --EXP: min 5 / mean 9.5 / max 14 / mode [(9, 7)]
#
# Monthly flight activity:
# PID  82 completed IPUG in  0 months. Awarded IP.
# PID  91 completed FLUG in  0 months. Awarded FL.
# PID 105 completed MQT  in  0 months. Awarded WG.
# PID 106 completed MQT  in  0 months. Awarded WG.
#
# Pilots departed: ['2x IP']
# >>>After outflow:
# EXPR: EXP    ->  25 |  INX    ->  10 |  PILOTS ->  35 | 71% EXP
# QUAL: IP     ->  21 |  FL     ->   6 |  WG     ->   8 |
# UPGS: (none) ->  33 |  IPUG   ->   2 |
#
# ---SIM MONTH 47---
# >>>After inflow/enrollment:
# ++ ['1x FL', '1x WG']
# EXPR: EXP    ->  26 |  INX    ->  11 |  PILOTS ->  37 | 70% EXP
# QUAL: IP     ->  21 |  FL     ->   7 |  WG     ->   9 |
# UPGS: (none) ->  33 |  IPUG   ->   3 |  FLUG   ->   1 |
#
# EOM INX sorties flown: 138 (avg. 6.9 per day / 12.5 SCM [INX])
# EOM INX support flown: 119
# -- Total EOM absorption sorties: 257 (avg. 12.8 per fly day)
# -- Total EOM non-absorption sorties: 134
# EOM total sorties remaining / available: 49 / 440 (88.9% - avg. 19.6 turned per day)
# EOM SCM summary:
# --INX: min 8 / mean 12.8 / max 15 / mode [(14, 4)]
# --EXP: min 3 / mean 9.5 / max 13 / mode [(12, 7)]
#
# Monthly flight activity:
# PID  81 completed IPUG in  1 months. Awarded IP.
# PID  83 completed IPUG in  1 months. Awarded IP.
# !! PID  87 experienced. TTE: 13 months. Inflow source? FTU
# PID  95 completed FLUG in  0 months. Awarded FL.
#
# Pilots departed: ['1x IP']
# >>>After outflow:
# EXPR: EXP    ->  26 |  INX    ->  10 |  PILOTS ->  36 | 72% EXP
# QUAL: IP     ->  22 |  FL     ->   6 |  WG     ->   8 |
# UPGS: (none) ->  35 |  IPUG   ->   1 |
#
# ---SIM MONTH 48---
# >>>After inflow/enrollment:
# ++ 1x MQT
# EXPR: EXP    ->  26 |  INX    ->  11 |  PILOTS ->  37 | 70% EXP
# QUAL: IP     ->  22 |  FL     ->   6 |  WG     ->   8 |  (none) ->   1 |
# UPGS: (none) ->  32 |  FLUG   ->   3 |  IPUG   ->   1 |  MQT    ->   1 |
#
# EOM INX sorties flown: 131 (avg. 6.5 per day / 11.9 SCM [INX])
# EOM INX support flown: 109
# -- Total EOM absorption sorties: 240 (avg. 12.0 per fly day)
# -- Total EOM non-absorption sorties: 119
# EOM total sorties remaining / available: 81 / 440 (81.6% - avg. 17.9 turned per day)
# EOM SCM summary:
# --INX: min 9 / mean 12.3 / max 15 / mode [(12, 3)]
# --EXP: min 2 / mean 8.5 / max 15 / mode [(9, 7)]
#
# Monthly flight activity:
# PID  96 completed FLUG in  0 months. Awarded FL.
# PID 104 completed FLUG in  0 months. Awarded FL.
# PID 107 completed IPUG in  1 months. Awarded IP.
# PID 108 completed FLUG in  0 months. Awarded FL.
# PID 109 completed MQT  in  0 months. Awarded WG.
#
# Pilots departed: []
# >>>After outflow:
# EXPR: EXP    ->  26 |  INX    ->  11 |  PILOTS ->  37 | 70% EXP
# QUAL: IP     ->  23 |  FL     ->   8 |  WG     ->   6 |
# UPGS: (none) ->  37 |
#
# ---SIM MONTH 49---
# >>>After inflow/enrollment:
# EXPR: EXP    ->  26 |  INX    ->  11 |  PILOTS ->  37 | 70% EXP
# QUAL: IP     ->  23 |  FL     ->   8 |  WG     ->   6 |
# UPGS: (none) ->  36 |  IPUG   ->   1 |
#
# EOM INX sorties flown: 123 (avg. 6.2 per day / 11.2 SCM [INX])
# EOM INX support flown: 65
# -- Total EOM absorption sorties: 188 (avg. 9.4 per fly day)
# -- Total EOM non-absorption sorties: 126
# EOM total sorties remaining / available: 126 / 440 (71.4% - avg. 15.7 turned per day)
# EOM SCM summary:
# --INX: min 8 / mean 11.3 / max 16 / mode [(10, 4)]
# --EXP: min 4 / mean 6.9 / max 11 / mode [(6, 6)]
#
# Monthly flight activity:
# !! PID 104 experienced. TTE:  5 months. Inflow source? nth tour
# !! PID 108 experienced. TTE:  2 months. Inflow source? nth tour
#
# Pilots departed: ['4x IP']
# >>>After outflow:
# EXPR: EXP    ->  24 |  INX    ->   9 |  PILOTS ->  33 | 73% EXP
# QUAL: IP     ->  19 |  FL     ->   8 |  WG     ->   6 |
# UPGS: (none) ->  32 |  IPUG   ->   1 |
#
# ---SIM MONTH 50---
# >>>After inflow/enrollment:
# ++ ['1x IP', '1x FL', '1x WG']
# EXPR: EXP    ->  26 |  INX    ->  10 |  PILOTS ->  36 | 72% EXP
# QUAL: IP     ->  20 |  FL     ->   9 |  WG     ->   7 |
# UPGS: (none) ->  31 |  IPUG   ->   4 |  FLUG   ->   1 |
#
# EOM INX sorties flown: 133 (avg. 6.7 per day / 13.3 SCM [INX])
# EOM INX support flown: 98
# -- Total EOM absorption sorties: 231 (avg. 11.6 per fly day)
# -- Total EOM non-absorption sorties: 147
# EOM total sorties remaining / available: 62 / 440 (85.9% - avg. 18.9 turned per day)
# EOM SCM summary:
# --INX: min 10 / mean 13.6 / max 16 / mode [(15, 3)]
# --EXP: min 4 / mean 9.1 / max 15 / mode [(9, 5)]
#
# Monthly flight activity:
# !! PID  91 experienced. TTE: 14 months. Inflow source? FTU
# PID  93 completed IPUG in  1 months. Awarded IP.
# PID  99 completed FLUG in  0 months. Awarded FL.
# PID 111 completed IPUG in  0 months. Awarded IP.
#
# Pilots departed: ['2x IP']
# >>>After outflow:
# EXPR: EXP    ->  25 |  INX    ->   9 |  PILOTS ->  34 | 74% EXP
# QUAL: IP     ->  20 |  FL     ->   8 |  WG     ->   6 |
# UPGS: (none) ->  32 |  IPUG   ->   2 |
#
# ---SIM MONTH 51---
# >>>After inflow/enrollment:
# ++ 2x MQT
# EXPR: EXP    ->  25 |  INX    ->  11 |  PILOTS ->  36 | 69% EXP
# QUAL: IP     ->  20 |  FL     ->   8 |  WG     ->   6 |  (none) ->   2 |
# UPGS: (none) ->  30 |  IPUG   ->   3 |  FLUG   ->   1 |  MQT    ->   2 |
#
# EOM INX sorties flown: 137 (avg. 6.8 per day / 12.5 SCM [INX])
# EOM INX support flown: 98
# -- Total EOM absorption sorties: 235 (avg. 11.8 per fly day)
# -- Total EOM non-absorption sorties: 135
# EOM total sorties remaining / available: 70 / 440 (84.1% - avg. 18.5 turned per day)
# EOM SCM summary:
# --INX: min 9 / mean 12.9 / max 18 / mode [(16, 2)]
# --EXP: min 3 / mean 9.0 / max 14 / mode [(8, 8)]
#
# Monthly flight activity:
# PID  88 completed IPUG in  1 months. Awarded IP.
# !! PID  95 experienced. TTE: 12 months. Inflow source? FTU
# !! PID  96 experienced. TTE: 12 months. Inflow source? FTU
# PID 104 completed IPUG in  1 months. Awarded IP.
# PID 108 completed IPUG in  0 months. Awarded IP.
# PID 112 completed FLUG in  0 months. Awarded FL.
# PID 113 completed MQT  in  0 months. Awarded WG.
# PID 114 completed MQT  in  0 months. Awarded WG.
#
# Pilots departed: ['2x IP']
# >>>After outflow:
# EXPR: EXP    ->  25 |  INX    ->   9 |  PILOTS ->  34 | 74% EXP
# QUAL: IP     ->  21 |  FL     ->   6 |  WG     ->   7 |
# UPGS: (none) ->  34 |
#
# ---SIM MONTH 52---
# >>>After inflow/enrollment:
# ++ ['1x FL', '1x WG']
# EXPR: EXP    ->  26 |  INX    ->  10 |  PILOTS ->  36 | 72% EXP
# QUAL: IP     ->  21 |  FL     ->   7 |  WG     ->   8 |
# UPGS: (none) ->  32 |  IPUG   ->   2 |  FLUG   ->   2 |
#
# EOM INX sorties flown: 139 (avg. 7.0 per day / 13.9 SCM [INX])
# EOM INX support flown: 113
# -- Total EOM absorption sorties: 252 (avg. 12.6 per fly day)
# -- Total EOM non-absorption sorties: 124
# EOM total sorties remaining / available: 64 / 440 (85.5% - avg. 18.8 turned per day)
# EOM SCM summary:
# --INX: min 12 / mean 14.1 / max 16 / mode [(14, 3)]
# --EXP: min 5 / mean 8.9 / max 13 / mode [(8, 8)]
#
# Monthly flight activity:
# PID 101 completed FLUG in  0 months. Awarded FL.
# !! PID 112 experienced. TTE:  2 months. Inflow source? nth tour
# PID 115 completed IPUG in  0 months. Awarded IP.
# PID 116 completed FLUG in  0 months. Awarded FL.
#
# Pilots departed: ['1x IP']
# >>>After outflow:
# EXPR: EXP    ->  26 |  INX    ->   9 |  PILOTS ->  35 | 74% EXP
# QUAL: IP     ->  21 |  FL     ->   8 |  WG     ->   6 |
# UPGS: (none) ->  34 |  IPUG   ->   1 |
#
# ---SIM MONTH 53---
# >>>After inflow/enrollment:
# ++ 1x MQT
# EXPR: EXP    ->  26 |  INX    ->  10 |  PILOTS ->  36 | 72% EXP
# QUAL: IP     ->  21 |  FL     ->   8 |  WG     ->   6 |  (none) ->   1 |
# UPGS: (none) ->  33 |  IPUG   ->   1 |  FLUG   ->   1 |  MQT    ->   1 |
#
# EOM INX sorties flown: 127 (avg. 6.3 per day / 12.7 SCM [INX])
# EOM INX support flown: 91
# -- Total EOM absorption sorties: 218 (avg. 10.9 per fly day)
# -- Total EOM non-absorption sorties: 134
# EOM total sorties remaining / available: 88 / 440 (80.0% - avg. 17.6 turned per day)
# EOM SCM summary:
# --INX: min 9 / mean 12.9 / max 16 / mode [(15, 3)]
# --EXP: min 4 / mean 8.4 / max 11 / mode [(11, 6)]
#
# Monthly flight activity:
# PID  87 completed IPUG in  1 months. Awarded IP.
# PID 100 completed FLUG in  0 months. Awarded FL.
# !! PID 116 experienced. TTE:  1 months. Inflow source? nth tour
# PID 117 completed MQT  in  0 months. Awarded WG.
#
# Pilots departed: []
# >>>After outflow:
# EXPR: EXP    ->  27 |  INX    ->   9 |  PILOTS ->  36 | 75% EXP
# QUAL: IP     ->  22 |  FL     ->   8 |  WG     ->   6 |
# UPGS: (none) ->  36 |
#
# ---SIM MONTH 54---
# >>>After inflow/enrollment:
# EXPR: EXP    ->  27 |  INX    ->   9 |  PILOTS ->  36 | 75% EXP
# QUAL: IP     ->  22 |  FL     ->   8 |  WG     ->   6 |
# UPGS: (none) ->  35 |  IPUG   ->   1 |
#
# EOM INX sorties flown: 138 (avg. 6.9 per day / 15.3 SCM [INX])
# EOM INX support flown: 91
# -- Total EOM absorption sorties: 229 (avg. 11.4 per fly day)
# -- Total EOM non-absorption sorties: 138
# EOM total sorties remaining / available: 73 / 440 (83.4% - avg. 18.4 turned per day)
# EOM SCM summary:
# --INX: min 13 / mean 15.8 / max 18 / mode [(17, 3)]
# --EXP: min 4 / mean 8.3 / max 13 / mode [(8, 8)]
#
# Monthly flight activity:
# !! PID  99 experienced. TTE: 13 months. Inflow source? FTU
#
# Pilots departed: ['2x IP']
# >>>After outflow:
# EXPR: EXP    ->  26 |  INX    ->   8 |  PILOTS ->  34 | 76% EXP
# QUAL: IP     ->  20 |  FL     ->   8 |  WG     ->   6 |
# UPGS: (none) ->  33 |  IPUG   ->   1 |
#
# ---SIM MONTH 55---
# >>>After inflow/enrollment:
# ++ 2x MQT
# EXPR: EXP    ->  26 |  INX    ->  10 |  PILOTS ->  36 | 72% EXP
# QUAL: IP     ->  20 |  FL     ->   8 |  WG     ->   6 |  (none) ->   2 |
# UPGS: (none) ->  31 |  IPUG   ->   2 |  FLUG   ->   1 |  MQT    ->   2 |
#
# EOM INX sorties flown: 141 (avg. 7.0 per day / 14.1 SCM [INX])
# EOM INX support flown: 116
# -- Total EOM absorption sorties: 257 (avg. 12.8 per fly day)
# -- Total EOM non-absorption sorties: 126
# EOM total sorties remaining / available: 57 / 440 (87.0% - avg. 19.1 turned per day)
# EOM SCM summary:
# --INX: min 11 / mean 14.2 / max 17 / mode [(15, 3)]
# --EXP: min 4 / mean 9.2 / max 12 / mode [(10, 5)]
#
# Monthly flight activity:
# PID  91 completed IPUG in  1 months. Awarded IP.
# !! PID 100 experienced. TTE: 12 months. Inflow source? FTU
# PID 105 completed FLUG in  0 months. Awarded FL.
# PID 116 completed IPUG in  0 months. Awarded IP.
# PID 118 completed MQT  in  0 months. Awarded WG.
# PID 119 completed MQT  in  0 months. Awarded WG.
#
# Pilots departed: ['3x IP']
# >>>After outflow:
# EXPR: EXP    ->  24 |  INX    ->   9 |  PILOTS ->  33 | 73% EXP
# QUAL: IP     ->  19 |  FL     ->   7 |  WG     ->   7 |
# UPGS: (none) ->  33 |
#
# ---SIM MONTH 56---
# >>>After inflow/enrollment:
# ++ ['3x IP']
# EXPR: EXP    ->  27 |  INX    ->   9 |  PILOTS ->  36 | 75% EXP
# QUAL: IP     ->  22 |  FL     ->   7 |  WG     ->   7 |
# UPGS: (none) ->  33 |  IPUG   ->   2 |  FLUG   ->   1 |
#
# EOM INX sorties flown: 132 (avg. 6.6 per day / 14.7 SCM [INX])
# EOM INX support flown: 109
# -- Total EOM absorption sorties: 241 (avg. 12.1 per fly day)
# -- Total EOM non-absorption sorties: 124
# EOM total sorties remaining / available: 75 / 440 (83.0% - avg. 18.2 turned per day)
# EOM SCM summary:
# --INX: min 12 / mean 15.0 / max 17 / mode [(16, 2)]
# --EXP: min 4 / mean 8.3 / max 13 / mode [(9, 5)]
#
# Monthly flight activity:
# PID  96 completed IPUG in  0 months. Awarded IP.
# PID 106 completed FLUG in  0 months. Awarded FL.
#
# Pilots departed: []
# >>>After outflow:
# EXPR: EXP    ->  27 |  INX    ->   9 |  PILOTS ->  36 | 75% EXP
# QUAL: IP     ->  23 |  FL     ->   7 |  WG     ->   6 |
# UPGS: (none) ->  35 |  IPUG   ->   1 |
#
# ---SIM MONTH 57---
# >>>After inflow/enrollment:
# EXPR: EXP    ->  27 |  INX    ->   9 |  PILOTS ->  36 | 75% EXP
# QUAL: IP     ->  23 |  FL     ->   7 |  WG     ->   6 |
# UPGS: (none) ->  33 |  IPUG   ->   2 |  FLUG   ->   1 |
#
# EOM INX sorties flown: 130 (avg. 6.5 per day / 14.4 SCM [INX])
# EOM INX support flown: 86
# -- Total EOM absorption sorties: 216 (avg. 10.8 per fly day)
# -- Total EOM non-absorption sorties: 115
# EOM total sorties remaining / available: 109 / 440 (75.2% - avg. 16.6 turned per day)
# EOM SCM summary:
# --INX: min 13 / mean 14.7 / max 20 / mode [(13, 3)]
# --EXP: min 3 / mean 7.3 / max 13 / mode [(6, 6)]
#
# Monthly flight activity:
# PID  95 completed IPUG in  1 months. Awarded IP.
# !! PID 101 experienced. TTE: 14 months. Inflow source? FTU
# PID 109 completed FLUG in  0 months. Awarded FL.
# PID 112 completed IPUG in  0 months. Awarded IP.
#
# Pilots departed: ['2x IP']
# >>>After outflow:
# EXPR: EXP    ->  26 |  INX    ->   8 |  PILOTS ->  34 | 76% EXP
# QUAL: IP     ->  23 |  FL     ->   6 |  WG     ->   5 |
# UPGS: (none) ->  34 |
#
# ---SIM MONTH 58---
# >>>After inflow/enrollment:
# ++ 2x MQT
# EXPR: EXP    ->  26 |  INX    ->  10 |  PILOTS ->  36 | 72% EXP
# QUAL: IP     ->  23 |  FL     ->   6 |  WG     ->   5 |  (none) ->   2 |
# UPGS: (none) ->  32 |  IPUG   ->   2 |  MQT    ->   2 |
#
# EOM INX sorties flown: 137 (avg. 6.8 per day / 13.7 SCM [INX])
# EOM INX support flown: 98
# -- Total EOM absorption sorties: 235 (avg. 11.8 per fly day)
# -- Total EOM non-absorption sorties: 151
# EOM total sorties remaining / available: 54 / 440 (87.7% - avg. 19.3 turned per day)
# EOM SCM summary:
# --INX: min 12 / mean 13.8 / max 16 / mode [(16, 3)]
# --EXP: min 6 / mean 9.3 / max 14 / mode [(7, 6)]
#
# Monthly flight activity:
# PID  99 completed IPUG in  0 months. Awarded IP.
# PID 123 completed MQT  in  0 months. Awarded WG.
# PID 124 completed MQT  in  0 months. Awarded WG.
#
# Pilots departed: ['2x IP']
# >>>After outflow:
# EXPR: EXP    ->  24 |  INX    ->  10 |  PILOTS ->  34 | 71% EXP
# QUAL: IP     ->  22 |  FL     ->   5 |  WG     ->   7 |
# UPGS: (none) ->  33 |  IPUG   ->   1 |
#
# ---SIM MONTH 59---
# >>>After inflow/enrollment:
# ++ ['2x FL']
# EXPR: EXP    ->  26 |  INX    ->  10 |  PILOTS ->  36 | 72% EXP
# QUAL: IP     ->  22 |  FL     ->   7 |  WG     ->   7 |
# UPGS: (none) ->  33 |  IPUG   ->   3 |
#
# EOM INX sorties flown: 142 (avg. 7.1 per day / 14.2 SCM [INX])
# EOM INX support flown: 105
# -- Total EOM absorption sorties: 247 (avg. 12.3 per fly day)
# -- Total EOM non-absorption sorties: 139
# EOM total sorties remaining / available: 54 / 440 (87.7% - avg. 19.3 turned per day)
# EOM SCM summary:
# --INX: min 9 / mean 14.4 / max 18 / mode [(18, 2)]
# --EXP: min 5 / mean 9.0 / max 15 / mode [(8, 5)]
#
# Monthly flight activity:
# PID 100 completed IPUG in  1 months. Awarded IP.
# !! PID 105 experienced. TTE: 13 months. Inflow source? FTU
# PID 125 completed IPUG in  0 months. Awarded IP.
#
# Pilots departed: ['1x IP']
# >>>After outflow:
# EXPR: EXP    ->  26 |  INX    ->   9 |  PILOTS ->  35 | 74% EXP
# QUAL: IP     ->  23 |  FL     ->   5 |  WG     ->   7 |
# UPGS: (none) ->  34 |  IPUG   ->   1 |
#
# ---SIM MONTH 60---
# >>>After inflow/enrollment:
# ++ 1x MQT
# EXPR: EXP    ->  26 |  INX    ->  10 |  PILOTS ->  36 | 72% EXP
# QUAL: IP     ->  23 |  FL     ->   5 |  WG     ->   7 |  (none) ->   1 |
# UPGS: (none) ->  32 |  IPUG   ->   2 |  FLUG   ->   1 |  MQT    ->   1 |
#
# EOM INX sorties flown: 135 (avg. 6.8 per day / 13.5 SCM [INX])
# EOM INX support flown: 111
# -- Total EOM absorption sorties: 246 (avg. 12.3 per fly day)
# -- Total EOM non-absorption sorties: 115
# EOM total sorties remaining / available: 79 / 440 (82.0% - avg. 18.1 turned per day)
# EOM SCM summary:
# --INX: min 8 / mean 13.8 / max 19 / mode [(14, 3)]
# --EXP: min 2 / mean 8.5 / max 13 / mode [(8, 5)]
#
# Monthly flight activity:
# PID 101 completed IPUG in  0 months. Awarded IP.
# !! PID 106 experienced. TTE: 14 months. Inflow source? FTU
# PID 113 completed FLUG in  0 months. Awarded FL.
# PID 126 completed IPUG in  1 months. Awarded IP.
# PID 127 completed MQT  in  0 months. Awarded WG.
#
# Pilots departed: []
# >>>After outflow:
# EXPR: EXP    ->  27 |  INX    ->   9 |  PILOTS ->  36 | 75% EXP
# QUAL: IP     ->  25 |  FL     ->   4 |  WG     ->   7 |
# UPGS: (none) ->  36 |

# %% [markdown]
# # Outputs

# %%
# sim.per_pilot_stats['TTE']

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker
import seaborn as sns
import pandas as pd

# %%
scm_inx = sim.monthly_stats['SCM_INX']
scm_exp = sim.monthly_stats['SCM_EXP']

df = pd.DataFrame(scm_inx).T.melt(var_name='month', value_name='SCM')
df['experience'] = 'INX'
df = pd.concat([df, pd.DataFrame(scm_exp).T.melt(var_name='month', value_name='SCM')]).fillna({'experience': 'EXP'}).dropna(subset=['SCM'])
df

plt.rcParams['figure.figsize'] = (30, 12)
sns.set_theme()
box = sns.catplot(data=df, y='SCM', x='month', hue='experience', kind='box', width=0.4, showmeans=True, showcaps=False, flierprops={'marker': 'x'}, meanprops={'marker': 'D', 'markeredgecolor': 'black', 'markerfacecolor': 'yellow', 'markersize': 4}, whiskerprops={'color': 'grey'}, height=8, aspect=3.5, legend=False)
box.ax.yaxis.set_major_locator(matplotlib.ticker.MultipleLocator(2.0))
box.ax.set_title('SCM distributions by experience level')
box.ax.axhline(9, color='red')
plt.legend()

# %%
foo = pd.concat([pd.DataFrame(sim.monthly_stats['NUM_IN_UGS']), 
           pd.DataFrame(sim.monthly_stats['NUM_BY_EXP']),
           pd.DataFrame(sim.monthly_stats['NUM_BY_QUAL'])], axis=1).rename(columns = {None: 'No upgrade',
                                                                  '': 'No qual',
                                                                  False: 'INX',
                                                                  True: 'EXP'}).fillna(0)

flows = pd.DataFrame({'first_arr': sim.monthly_stats['FIRST_ARRIVALS'], 'first_dep': sim.monthly_stats['FIRST_DEPARTURES'],
              'nth_arr': sim.monthly_stats['NTH_ARRIVALS'], 'nth_dep': sim.monthly_stats['NTH_DEPARTURES']})

flows = flows.assign(net_first = lambda df: df.first_arr - df.first_dep,
                     net_nth = lambda df: df.nth_arr - df.nth_dep,
                     first_cum = lambda df: df.net_first.cumsum(),
                     nth_cum = lambda df: df.net_nth.cumsum())

# %%
 ax = flows[['net_first', 'net_nth']].plot(kind='bar')
 ax.axhline(0, color='black')
 ax.set_xlabel('month')
 ax.set_ylabel('net gain/loss by first v. nth tour')

 flows[['first_cum', 'nth_cum']].plot(kind='line', ax=ax)

# %%
absorbed = pd.DataFrame([row for row in sim.per_pilot_stats['TTE'] if row['Absorbable']])
absorbed['EXP year'] = absorbed['EXP month'].floordiv(12)
absorbed
# Out:
#     PID      Source  TTE  EXP month  Absorbable  EXP year
# 0     1  initial WG   24          3        True         0
# 1    12  initial WG   19          5        True         0
# 2    13  initial WG   22          7        True         0
# 3     4  initial WG   18          8        True         0
# 4     9  initial WG   24          8        True         0
# 5    11  initial WG   18         10        True         0
# 6     8  initial WG   18         11        True         0
# 7    15  initial WG   17         11        True         0
# 8     2  initial WG   22         13        True         1
# 9    10     initial   16         15        True         1
# 10   14  initial WG   18         15        True         1
# 11   40         FTU   17         20        True         1
# 12   41         FTU   17         20        True         1
# 13   44         FTU   15         20        True         1
# 14   46         FTU   14         21        True         1
# 15   45         FTU   15         22        True         1
# 16   51         FTU   14         24        True         2
# 17   50         FTU   15         25        True         2
# 18   54         FTU   14         26        True         2
# 19   58         FTU   14         29        True         2
# 20   59         FTU   14         29        True         2
# 21   62         FTU   13         30        True         2
# 22   63         FTU   13         32        True         2
# 23   64         FTU   13         32        True         2
# 24   69         FTU   13         35        True         2
# 25   68         FTU   14         36        True         3
# 26   72         FTU   13         37        True         3
# 27   77         FTU   11         38        True         3
# 28   78         FTU   12         39        True         3
# 29   81         FTU   12         41        True         3
# 30   83         FTU   11         42        True         3
# 31   82         FTU   12         43        True         3
# 32   88         FTU   11         45        True         3
# 33   87         FTU   13         47        True         3
# 34   91         FTU   14         50        True         4
# 35   95         FTU   12         51        True         4
# 36   96         FTU   12         51        True         4
# 37   99         FTU   13         54        True         4
# 38  100         FTU   12         55        True         4
# 39  101         FTU   14         57        True         4
# 40  105         FTU   13         59        True         4
# 41  106         FTU   14         60        True         5

# %%
absorption = pd.DataFrame([len(absorbed[absorbed['EXP month'] == month]) for month in range(60)], columns=['absorbed']).rename_axis('month')
absorption['absorbed'] = absorption.cumsum()

# %%
plt.rcParams['figure.figsize'] = (30, 12)
foo['ratio'] = foo['EXP'] / foo[['EXP', 'INX']].sum(axis=1)
ax = foo[['No qual', 'WG', 'FL', 'IP']].plot(kind='bar', stacked=True, colormap='winter_r', alpha=0.6)
for year in range(1, int(len(absorption) / 12)):
    ax.axvline(year*12 + 0.5, linestyle='--', lw=1.5, c='gray')
    
foo[['INX', 'EXP']].plot(kind='line', ax=ax, linewidth=3, color=['red', 'black'])
absorption['absorbed'].plot(kind='line', ax=ax, linewidth=3, color=['black'], style=':')
plt.legend()
ax.set_xlabel('month')
ax.set_ylabel('# pilots')
ax.set_title('Unit manning by qualifications')
# Out:
# Text(0.5, 1.0, 'Unit manning by qualifications')

# %%
plt.rcParams['figure.figsize'] = (12, 12)
absorbed['TTE'].plot.hist(bins=range(0, 36, 3))
plt.xticks(range(0, 36, 3))
plt.xlabel('TTE (months)')
# Out:
# Text(0.5, 0, 'TTE (months)')

# %%
foo['total'] = foo[['No qual', 'WG', 'FL', 'IP']].sum(axis=1)
for qual in ['No qual', 'WG', 'FL', 'IP']:
    foo[f'{qual}_pct'] = foo[qual] / foo['total']

# %%
plt.rcParams['figure.figsize'] = (12, 30)
foo.loc[::-1, 'No qual_pct':].plot(kind='barh', stacked=True)

# %%
check = pd.DataFrame({'PID': [p.id for p in sim.sq.pilots],
                      'Qual': [sim.sq._get_highest_quals(pilots=[p])[-1] for p in sim.sq.pilots],
                      'EXP': [p.experienced for p in sim.sq.pilots]})

pd.crosstab(check['EXP'], check['Qual'])
# Out:
# Qual   FL  IP  WG
# EXP
# False   2   0   7
# True    2  25   0

# %%
per_year = absorbed.groupby('EXP year').size()
per_year
# Out:
# EXP year
# 0    8
# 1    8
# 2    9
# 3    9
# 4    7
# 5    1
# dtype: int64

# %%
per_year[:5].mean()
# Out:
# 8.2
